# %% [markdown]
# ![cars.jpg](attachment:cars.jpg)

# %% [markdown]
# __Що ми хочемо дізнатись:__
#     <li> розбивку по областях </li>
#     <li> які найпопулярніші марки авто в Україні </li>
#     <li> як часто перереєструють автомобілі N року випуску  </li>
#     <li> як реєструють електрокари на первинному ринку </li>
#     <li> як часто перепродають електрокари </li>

# %% [markdown]
# __імпортуємо бібілотеки__

# %%
import requests
import json
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from pprint import pprint as pp
import re
import seaborn as sns

# Для роботи із .zip файлами
import io
import zipfile
import os 
import csv

# %% [markdown]
# # Працюємо із АРІ порталу

# %% [markdown]
# __Робимо запит до АРІ Data.gov.ua__
# документація по роботі із АРІ Порталу:
# ідентифікаційний номер набору даних по реєстрації авто в Україні: 	06779371-308f-42d7-895e-5a39833375f0
# посилання на набір даних: https://data.gov.ua/dataset/06779371-308f-42d7-895e-5a39833375f0

# %%
response = requests.get("https://data.gov.ua/api/3/action/package_show?id=06779371-308f-42d7-895e-5a39833375f0").json()
pp(response) #переглядаємо вміст відповіді
# Out:
# {'help': 'https://data.gov.ua/api/3/action/help_show?name=package_show',
#  'result': {'archiver': {'is_broken': False,
#                          'reason': '',
#                          'status': 'Archived successfully',
#                          'status_id': 0},
#             'author': 'rodger_236',
#             'author_email': 'rodger@mvs.gov.ua',
#             'creator_user_id': '109cb3b1-5415-4457-8280-f927e9cc5335',
#             'groups': [{'description': 'Все що стосується Верховної ради та '
#                                        'питань загальнодаржавного характеру',
#                         'display_name': 'Держава',
#                         'id': '6c734e97-52f5-40a1-9cb5-81b5ebb15e43',
#                         'image_display_url': 'https://data.gov.ua/uploads/group/2018-08-09-052819.023276bank-2.svg',
#                         'name': 'derzhava',
#                         'title': 'Держава'},
#                        {'description': 'Арештоване Майно, все про компанії, '
#                                        "всі питання пов'язані з веденням "
#                                        'господарської діяльності',
#                         'display_name': 'Економіка та бізнес',
#                         'id': 'cf86192b-ea11-4572-909b-2a78d2aa43c4',
#                         'image_display_url': 'https://data.gov.ua/uploads/group/2018-08-09-053035.138982graph-pie-1.svg',
#                         'name': 'ekonomika',
#                         'title': 'Економіка та бізнес'},
#                        {'description': '',
#                         'display_name': 'Транспорт',
#                         'id': '75280156-1c8f-4943-b78e-3d4d051febca',
#                         'image_display_url': 'https://data.gov.ua/uploads/group/2018-08-09-053520.444396truck-1.svg',
#                         'name': 'transport',
#                         'title': 'Транспорт'}],
#             'id': '0ffd8b75-0628-48cc-952a-9302f9799ec0',
#             'is_datapackage': 'true',
#             'isopen': True,
#             'language': 'ua',
#             'license_id': 'cc-by',
#             'license_title': 'Creative Commons Attribution',
#             'license_url': 'http://www.opendefinition.org/licenses/cc-by',
#             'maintainer': 'Кішман Назарій Костянтинович',
#             'maintainer_email': 'n.kishman@hsc.gov.ua',
#             'metadata_created': '2018-08-22T14:52:50.808591',
#             'metadata_modified': '2021-04-01T13:58:39.535532',
#             'name': '06779371-308f-42d7-895e-5a39833375f0',
#             'notes': 'Відомості про транспортні засоби та їх власників',
#             'num_resources': 9,
#             'num_tags': 9,
#             'organization': {'approval_status': 'approved',
#                              'created': '2018-08-08T19:51:52.510953',
#                              'description': '<ol>\r\n'
#                                             '<li>[Положення про Міністерство '
#                                             'внутрішніх справ '
#                                             'України](https://zakon.rada.gov.ua/laws/show/878-2015-%D0%BF#Text)\r\n'
#                                             '\r\n'
#                                             '\r\n'
#                                             '<li>[Єдиний портал органів '
#                                             'системи '
#                                             'МВС](https://mvs.gov.ua/)\r\n'
#                                             '\r\n'
#                                             '\r\n'
#                                             '<li>Адреса: 01601, м. Київ, вул. '
#                                             'Академіка Богомольця, 10\r\n'
#                                             '</ol>',
#                              'id': '13d9803c-5c4d-47e8-b89f-3d6017c78ef9',
#                              'image_url': '2018-08-20-155911.407974MVS.png',
#                              'is_organization': True,
#                              'name': 'ministerstvo-vnutrishnikh-sprav-ukrayiny',
#                              'revision_id': 'c459e90e-efc5-4311-b26e-52c041438217',
#                              'state': 'active',
#                              'title': 'Міністерство внутрішніх справ України',
#                              'type': 'organization'},
#             'owner_org': '13d9803c-5c4d-47e8-b89f-3d6017c78ef9',
#             'private': False,
#             'purpose_of_collecting_information': 'Закону України “Про дорожній '
#                                                  'рух”',
#             'qa': {'openness_score': 3,
#                    'openness_score_reason': 'Content of file appeared to be '
#                                             'format "%s" which receives '
#                                             'openness score: %s.',
#                    'openness_score_reason_args': '[["CSV", 3]]',
#                    'updated': '2020-07-12T20:25:50.175167'},
#             'relationships_as_object': [],
#             'relationships_as_subject': [],
#             'resources': [{'archiver': {'cache_filepath': '/mnt/storage/ckan/default/resources/013/237/40-88df-46c2-b06e-fbb58c89fe17',
#                                         'cache_url': 'https://data.gov.ua/dataset/0ffd8b75-0628-48cc-952a-9302f9799ec0/resource/01323740-88df-46c2-b06e-fbb58c89fe17/download/tz_opendata_z01012018_po01012019.zip',
#                                         'created': '2018-08-29T13:27:10.920027',
#                                         'etag': None,
#                                         'failure_count': 0,
#                                         'first_failure': None,
#                                         'hash': 'eb68085e63d7feec4ba386dbb0c1a56449a1c300',
#                                         'is_broken': False,
#                                         'is_broken_printable': 'Downloaded OK',
#                                         'last_modified': None,
#                                         'last_success': '2020-07-14T13:01:15.498976',
#                                         'mimetype': 'application/zip',
#                                         'reason': '',
#                                         'resource_timestamp': '2020-07-01T10:18:11.431294',
#                                         'size': 65881530,
#                                         'status': 'Archived successfully',
#                                         'status_id': 0,
#                                         'updated': '2020-07-14T13:01:15.498976',
#                                         'url_redirected_to': 'https://data.gov.ua/dataset/0ffd8b75-0628-48cc-952a-9302f9799ec0/resource/01323740-88df-46c2-b06e-fbb58c89fe17/download/tz_opendata_z01012018_po01012019.zip'},
#                            'cache_last_updated': None,
#                            'cache_url': None,
#                            'created': '2018-08-29T09:46:39.836198',
#                            'datastore_active': False,
#                            'description': 'Дані щодо транспортних засобів за '
#                                           '2018 рік',
#                            'file_hash_sum': 'ddecf604fe6a67514e1bab50b4aea6c7',
#                            'format': 'csv, zip',
#                            'hash': '',
#                            'id': '01323740-88df-46c2-b06e-fbb58c89fe17',
#                            'last_modified': '2019-01-09T10:11:28.600464',
#                            'mimetype': 'application/zip',
#                            'mimetype_inner': None,
#                            'name': 'reestrTZ2018',
#                            'package_id': '0ffd8b75-0628-48cc-952a-9302f9799ec0',
#                            'position': 0,
#                            'qa': {'archival_timestamp': '2020-06-29T13:12:18.884691',
#                                   'created': '2018-08-29T14:25:21.073435',
#                                   'format': 'CSV',
#                                   'openness_score': 3,
#                                   'openness_score_reason': 'Content of file '
#                                                            'appeared to be '
#                                                            'format "%s" which '
#                                                            'receives openness '
#                                                            'score: %s.',
#                                   'openness_score_reason_args': '[["CSV", 3]]',
#                                   'resource_timestamp': None,
#                                   'updated': '2020-07-12T20:25:50.065542'},
#                            'resource_type': None,
#                            'revision_id': '611bb3f5-05ea-41bd-916b-b4996c7dbaaf',
#                            'size': 65881530,
#                            'state': 'active',
#                            'url': 'https://data.gov.ua/dataset/0ffd8b75-0628-48cc-952a-9302f9799ec0/resource/01323740-88df-46c2-b06e-fbb58c89fe17/download/tz_opendata_z01012018_po01012019.zip',
#                            'url_type': 'upload'},
#                           {'archiver': {'cache_filepath': '/mnt/storage/ckan/default/resources/9ce/323/52-bd11-4324-a2b4-5addbd228b1b',
#                                         'cache_url': 'https://data.gov.ua/dataset/0ffd8b75-0628-48cc-952a-9302f9799ec0/resource/9ce32352-bd11-4324-a2b4-5addbd228b1b/download/tz_opendata_z01012017_po31122017.zip',
#                                         'created': '2018-08-29T13:27:12.563205',
#                                         'etag': None,
#                                         'failure_count': 0,
#                                         'first_failure': None,
#                                         'hash': 'f6dd782056be777d7c2990f490edb2af1eacff06',
#                                         'is_broken': False,
#                                         'is_broken_printable': 'Downloaded OK',
#                                         'last_modified': None,
#                                         'last_success': '2020-07-14T13:01:16.667051',
#                                         'mimetype': 'application/zip',
#                                         'reason': '',
#                                         'resource_timestamp': '2020-07-01T10:18:11.431294',
#                                         'size': 58960358,
#                                         'status': 'Archived successfully',
#                                         'status_id': 0,
#                                         'updated': '2020-07-14T13:01:16.667051',
#                                         'url_redirected_to': 'https://data.gov.ua/dataset/0ffd8b75-0628-48cc-952a-9302f9799ec0/resource/9ce32352-bd11-4324-a2b4-5addbd228b1b/download/tz_opendata_z01012017_po31122017.zip'},
#                            'cache_last_updated': None,
#                            'cache_url': None,
#                            'created': '2018-08-29T09:49:46.791474',
#                            'datastore_active': False,
#                            'description': 'Дані щодо транспортних засобів за '
#                                           '2017 рік',
#                            'file_hash_sum': 'ddecf604fe6a67514e1bab50b4aea6c7',
#                            'format': 'csv, zip',
#                            'hash': '',
#                            'id': '9ce32352-bd11-4324-a2b4-5addbd228b1b',
#                            'last_modified': '2018-08-29T09:49:46.621825',
#                            'mimetype': 'application/zip',
#                            'mimetype_inner': None,
#                            'name': 'reestrTZ2017',
#                            'package_id': '0ffd8b75-0628-48cc-952a-9302f9799ec0',
#                            'position': 1,
#                            'qa': {'archival_timestamp': '2020-06-29T13:12:19.810074',
#                                   'created': '2018-08-29T14:25:21.120570',
#                                   'format': 'CSV',
#                                   'openness_score': 3,
#                                   'openness_score_reason': 'Content of file '
#                                                            'appeared to be '
#                                                            'format "%s" which '
#                                                            'receives openness '
#                                                            'score: %s.',
#                                   'openness_score_reason_args': '[["CSV", 3]]',
#                                   'resource_timestamp': None,
#                                   'updated': '2020-07-12T20:25:50.087693'},
#                            'resource_type': None,
#                            'revision_id': '611bb3f5-05ea-41bd-916b-b4996c7dbaaf',
#                            'size': 58960358,
#                            'state': 'active',
#                            'url': 'https://data.gov.ua/dataset/0ffd8b75-0628-48cc-952a-9302f9799ec0/resource/9ce32352-bd11-4324-a2b4-5addbd228b1b/download/tz_opendata_z01012017_po31122017.zip',
#                            'url_type': 'upload'},
#                           {'archiver': {'cache_filepath': '/mnt/storage/ckan/default/resources/7bd/c2a/1b-5399-4ab0-97e0-633e68837b04',
#                                         'cache_url': 'https://data.gov.ua/dataset/0ffd8b75-0628-48cc-952a-9302f9799ec0/resource/7bdc2a1b-5399-4ab0-97e0-633e68837b04/download/tz_opendata_z01012016_po31122016.zip',
#                                         'created': '2018-08-29T13:27:14.106595',
#                                         'etag': None,
#                                         'failure_count': 0,
#                                         'first_failure': None,
#                                         'hash': '4c43ddc255550dba90d8cae690456dd016b9ec5e',
#                                         'is_broken': False,
#                                         'is_broken_printable': 'Downloaded OK',
#                                         'last_modified': None,
#                                         'last_success': '2020-07-14T13:01:17.983111',
#                                         'mimetype': 'application/zip',
#                                         'reason': '',
#                                         'resource_timestamp': '2020-07-01T10:18:11.431294',
#                                         'size': 59325373,
#                                         'status': 'Archived successfully',
#                                         'status_id': 0,
#                                         'updated': '2020-07-14T13:01:17.983111',
#                                         'url_redirected_to': 'https://data.gov.ua/dataset/0ffd8b75-0628-48cc-952a-9302f9799ec0/resource/7bdc2a1b-5399-4ab0-97e0-633e68837b04/download/tz_opendata_z01012016_po31122016.zip'},
#                            'cache_last_updated': None,
#                            'cache_url': None,
#                            'created': '2018-08-29T09:52:13.661163',
#                            'datastore_active': False,
#                            'description': 'Дані щодо транспортних засобів за '
#                                           '2016 рік',
#                            'file_hash_sum': 'ddecf604fe6a67514e1bab50b4aea6c7',
#                            'format': 'csv, zip',
#                            'hash': '',
#                            'id': '7bdc2a1b-5399-4ab0-97e0-633e68837b04',
#                            'last_modified': '2018-08-29T09:52:13.336499',
#                            'mimetype': 'application/zip',
#                            'mimetype_inner': None,
#                            'name': 'reestrTZ2016',
#                            'package_id': '0ffd8b75-0628-48cc-952a-9302f9799ec0',
#                            'position': 2,
#                            'qa': {'archival_timestamp': '2020-06-29T13:12:20.733769',
#                                   'created': '2018-08-29T14:25:21.156085',
#                                   'format': 'CSV',
#                                   'openness_score': 3,
#                                   'openness_score_reason': 'Content of file '
#                                                            'appeared to be '
#                                                            'format "%s" which '
#                                                            'receives openness '
#                                                            'score: %s.',
#                                   'openness_score_reason_args': '[["CSV", 3]]',
#                                   'resource_timestamp': None,
#                                   'updated': '2020-07-12T20:25:50.105146'},
#                            'resource_type': None,
#                            'revision_id': '611bb3f5-05ea-41bd-916b-b4996c7dbaaf',
#                            'size': 59325373,
#                            'state': 'active',
#                            'url': 'https://data.gov.ua/dataset/0ffd8b75-0628-48cc-952a-9302f9799ec0/resource/7bdc2a1b-5399-4ab0-97e0-633e68837b04/download/tz_opendata_z01012016_po31122016.zip',
#                            'url_type': 'upload'},
#                           {'archiver': {'cache_filepath': '/mnt/storage/ckan/default/resources/09c/606/dc-d740-40db-96f0-e679eeca6ace',
#                                         'cache_url': 'https://data.gov.ua/dataset/0ffd8b75-0628-48cc-952a-9302f9799ec0/resource/09c606dc-d740-40db-96f0-e679eeca6ace/download/tz_opendata_z01012015_po31122015.zip',
#                                         'created': '2018-08-29T13:27:15.757383',
#                                         'etag': None,
#                                         'failure_count': 0,
#                                         'first_failure': None,
#                                         'hash': '29c3e24f368723dc8466a208bf3d74dbe39cc30b',
#                                         'is_broken': False,
#                                         'is_broken_printable': 'Downloaded OK',
#                                         'last_modified': None,
#                                         'last_success': '2020-07-14T13:01:19.170405',
#                                         'mimetype': 'application/zip',
#                                         'reason': '',
#                                         'resource_timestamp': '2020-07-01T10:18:11.431294',
#                                         'size': 62248522,
#                                         'status': 'Archived successfully',
#                                         'status_id': 0,
#                                         'updated': '2020-07-14T13:01:19.170405',
#                                         'url_redirected_to': 'https://data.gov.ua/dataset/0ffd8b75-0628-48cc-952a-9302f9799ec0/resource/09c606dc-d740-40db-96f0-e679eeca6ace/download/tz_opendata_z01012015_po31122015.zip'},
#                            'cache_last_updated': None,
#                            'cache_url': None,
#                            'created': '2018-08-29T09:55:19.460400',
#                            'datastore_active': False,
#                            'description': 'Дані щодо транспортних засобів за '
#                                           '2015 рік',
#                            'file_hash_sum': 'ddecf604fe6a67514e1bab50b4aea6c7',
#                            'format': 'csv, zip',
#                            'hash': '',
#                            'id': '09c606dc-d740-40db-96f0-e679eeca6ace',
#                            'last_modified': '2018-08-29T09:55:19.282530',
#                            'mimetype': 'application/zip',
#                            'mimetype_inner': None,
#                            'name': 'reestrTZ2015',
#                            'package_id': '0ffd8b75-0628-48cc-952a-9302f9799ec0',
#                            'position': 3,
#                            'qa': {'archival_timestamp': '2020-06-29T13:12:23.106556',
#                                   'created': '2018-08-29T14:25:21.188430',
#                                   'format': 'CSV',
#                                   'openness_score': 3,
#                                   'openness_score_reason': 'Content of file '
#                                                            'appeared to be '
#                                                            'format "%s" which '
#                                                            'receives openness '
#                                                            'score: %s.',
#                                   'openness_score_reason_args': '[["CSV", 3]]',
#                                   'resource_timestamp': None,
#                                   'updated': '2020-07-12T20:25:50.119557'},
#                            'resource_type': None,
#                            'revision_id': '611bb3f5-05ea-41bd-916b-b4996c7dbaaf',
#                            'size': 62248522,
#                            'state': 'active',
#                            'url': 'https://data.gov.ua/dataset/0ffd8b75-0628-48cc-952a-9302f9799ec0/resource/09c606dc-d740-40db-96f0-e679eeca6ace/download/tz_opendata_z01012015_po31122015.zip',
#                            'url_type': 'upload'},
#                           {'archiver': {'cache_filepath': '/mnt/storage/ckan/default/resources/80a/115/ae-61df-4a13-8771-36c2826268df',
#                                         'cache_url': 'https://data.gov.ua/dataset/0ffd8b75-0628-48cc-952a-9302f9799ec0/resource/80a115ae-61df-4a13-8771-36c2826268df/download/tz_opendata_z01012014_po31122014.zip',
#                                         'created': '2018-08-29T13:27:17.784703',
#                                         'etag': None,
#                                         'failure_count': 0,
#                                         'first_failure': None,
#                                         'hash': '671a1294bfad5eca2b53261c423937d4560b542d',
#                                         'is_broken': False,
#                                         'is_broken_printable': 'Downloaded OK',
#                                         'last_modified': None,
#                                         'last_success': '2020-07-14T13:01:20.207434',
#                                         'mimetype': 'application/zip',
#                                         'reason': '',
#                                         'resource_timestamp': '2020-07-01T10:18:11.431294',
#                                         'size': 72196197,
#                                         'status': 'Archived successfully',
#                                         'status_id': 0,
#                                         'updated': '2020-07-14T13:01:20.207434',
#                                         'url_redirected_to': 'https://data.gov.ua/dataset/0ffd8b75-0628-48cc-952a-9302f9799ec0/resource/80a115ae-61df-4a13-8771-36c2826268df/download/tz_opendata_z01012014_po31122014.zip'},
#                            'cache_last_updated': None,
#                            'cache_url': None,
#                            'created': '2018-08-29T09:57:11.181086',
#                            'datastore_active': False,
#                            'description': 'Дані щодо транспортних засобів за '
#                                           '2014 рік',
#                            'file_hash_sum': 'ddecf604fe6a67514e1bab50b4aea6c7',
#                            'format': 'csv, zip',
#                            'hash': '',
#                            'id': '80a115ae-61df-4a13-8771-36c2826268df',
#                            'last_modified': '2018-08-29T09:57:10.984384',
#                            'mimetype': 'application/zip',
#                            'mimetype_inner': None,
#                            'name': 'reestrTZ2014',
#                            'package_id': '0ffd8b75-0628-48cc-952a-9302f9799ec0',
#                            'position': 4,
#                            'qa': {'archival_timestamp': '2020-06-29T13:12:24.033111',
#                                   'created': '2018-08-29T14:25:21.216216',
#                                   'format': 'CSV',
#                                   'openness_score': 3,
#                                   'openness_score_reason': 'Content of file '
#                                                            'appeared to be '
#                                                            'format "%s" which '
#                                                            'receives openness '
#                                                            'score: %s.',
#                                   'openness_score_reason_args': '[["CSV", 3]]',
#                                   'resource_timestamp': None,
#                                   'updated': '2020-07-12T20:25:50.139035'},
#                            'resource_type': None,
#                            'revision_id': '611bb3f5-05ea-41bd-916b-b4996c7dbaaf',
#                            'size': 72196197,
#                            'state': 'active',
#                            'url': 'https://data.gov.ua/dataset/0ffd8b75-0628-48cc-952a-9302f9799ec0/resource/80a115ae-61df-4a13-8771-36c2826268df/download/tz_opendata_z01012014_po31122014.zip',
#                            'url_type': 'upload'},
#                           {'archiver': {'cache_filepath': '/mnt/storage/ckan/default/resources/86a/954/8b-8323-4fa2-972e-0692edf6959f',
#                                         'cache_url': 'https://data.gov.ua/dataset/0ffd8b75-0628-48cc-952a-9302f9799ec0/resource/86a9548b-8323-4fa2-972e-0692edf6959f/download/tz_opendata_z01012013_po31122013.zip',
#                                         'created': '2018-08-29T13:27:19.372350',
#                                         'etag': None,
#                                         'failure_count': 0,
#                                         'first_failure': None,
#                                         'hash': 'e351f06ac87fadfc992f3e71913fb24368cc2fde',
#                                         'is_broken': False,
#                                         'is_broken_printable': 'Downloaded OK',
#                                         'last_modified': None,
#                                         'last_success': '2020-07-14T13:01:21.421412',
#                                         'mimetype': 'application/zip',
#                                         'reason': '',
#                                         'resource_timestamp': '2020-07-01T10:18:11.431294',
#                                         'size': 97367430,
#                                         'status': 'Archived successfully',
#                                         'status_id': 0,
#                                         'updated': '2020-07-14T13:01:21.421412',
#                                         'url_redirected_to': 'https://data.gov.ua/dataset/0ffd8b75-0628-48cc-952a-9302f9799ec0/resource/86a9548b-8323-4fa2-972e-0692edf6959f/download/tz_opendata_z01012013_po31122013.zip'},
#                            'cache_last_updated': None,
#                            'cache_url': None,
#                            'created': '2018-08-29T09:59:18.448205',
#                            'datastore_active': False,
#                            'description': 'Дані щодо транспортних засобів за '
#                                           '2013 рік',
#                            'file_hash_sum': 'ddecf604fe6a67514e1bab50b4aea6c7',
#                            'format': 'csv, zip',
#                            'hash': '',
#                            'id': '86a9548b-8323-4fa2-972e-0692edf6959f',
#                            'last_modified': '2018-08-29T09:59:18.233317',
#                            'mimetype': 'application/zip',
#                            'mimetype_inner': None,
#                            'name': 'reestrTZ2013',
#                            'package_id': '0ffd8b75-0628-48cc-952a-9302f9799ec0',
#                            'position': 5,
#                            'qa': {'archival_timestamp': '2020-06-29T13:12:24.992663',
#                                   'created': '2018-08-29T14:25:21.242646',
#                                   'format': 'CSV',
#                                   'openness_score': 3,
#                                   'openness_score_reason': 'Content of file '
#                                                            'appeared to be '
#                                                            'format "%s" which '
#                                                            'receives openness '
#                                                            'score: %s.',
#                                   'openness_score_reason_args': '[["CSV", 3]]',
#                                   'resource_timestamp': None,
#                                   'updated': '2020-07-12T20:25:50.152914'},
#                            'resource_type': None,
#                            'revision_id': '611bb3f5-05ea-41bd-916b-b4996c7dbaaf',
#                            'size': 97367430,
#                            'state': 'active',
#                            'url': 'https://data.gov.ua/dataset/0ffd8b75-0628-48cc-952a-9302f9799ec0/resource/86a9548b-8323-4fa2-972e-0692edf6959f/download/tz_opendata_z01012013_po31122013.zip',
#                            'url_type': 'upload'},
#                           {'archiver': {'cache_filepath': '/mnt/storage/ckan/default/resources/7a5/8e8/f7-9323-47d4-a21d-19486e014eb4',
#                                         'cache_url': 'https://data.gov.ua/dataset/0ffd8b75-0628-48cc-952a-9302f9799ec0/resource/7a58e8f7-9323-47d4-a21d-19486e014eb4/download/tz_opendata_z01012019_po01012020.zip',
#                                         'created': '2019-02-08T22:56:12.313700',
#                                         'etag': None,
#                                         'failure_count': 0,
#                                         'first_failure': None,
#                                         'hash': '7792f6d6ed3e8e8878d12524579991ae19cafc17',
#                                         'is_broken': False,
#                                         'is_broken_printable': 'Downloaded OK',
#                                         'last_modified': None,
#                                         'last_success': '2020-07-14T13:01:22.439108',
#                                         'mimetype': 'application/zip',
#                                         'reason': '',
#                                         'resource_timestamp': '2020-07-01T10:18:11.431294',
#                                         'size': 86785142,
#                                         'status': 'Archived successfully',
#                                         'status_id': 0,
#                                         'updated': '2020-07-14T13:01:22.439108',
#                                         'url_redirected_to': 'https://data.gov.ua/dataset/0ffd8b75-0628-48cc-952a-9302f9799ec0/resource/7a58e8f7-9323-47d4-a21d-19486e014eb4/download/tz_opendata_z01012019_po01012020.zip'},
#                            'cache_last_updated': None,
#                            'cache_url': None,
#                            'created': '2019-02-08T10:23:37.629614',
#                            'datastore_active': False,
#                            'description': 'Дані щодо транспортних засобів за '
#                                           '2019 рік',
#                            'file_hash_sum': 'ddecf604fe6a67514e1bab50b4aea6c7',
#                            'format': 'csv, zip',
#                            'hash': '',
#                            'id': '7a58e8f7-9323-47d4-a21d-19486e014eb4',
#                            'last_modified': '2020-01-09T14:39:16.078700',
#                            'mimetype': 'application/zip',
#                            'mimetype_inner': None,
#                            'name': 'reestrTZ2019',
#                            'package_id': '0ffd8b75-0628-48cc-952a-9302f9799ec0',
#                            'position': 6,
#                            'qa': {'archival_timestamp': '2020-06-29T13:12:25.945605',
#                                   'created': '2019-02-09T06:10:03.682772',
#                                   'format': 'ZIP',
#                                   'openness_score': 1,
#                                   'openness_score_reason': 'Content of file '
#                                                            'appeared to be '
#                                                            'format "%s" which '
#                                                            'receives openness '
#                                                            'score: %s.',
#                                   'openness_score_reason_args': '[["ZIP", 1]]',
#                                   'resource_timestamp': None,
#                                   'updated': '2020-07-12T20:25:50.162967'},
#                            'resource_type': None,
#                            'revision_id': '611bb3f5-05ea-41bd-916b-b4996c7dbaaf',
#                            'size': 86785142,
#                            'state': 'active',
#                            'url': 'https://data.gov.ua/dataset/0ffd8b75-0628-48cc-952a-9302f9799ec0/resource/7a58e8f7-9323-47d4-a21d-19486e014eb4/download/tz_opendata_z01012019_po01012020.zip',
#                            'url_type': 'upload'},
#                           {'archiver': {'cache_filepath': '/mnt/storage/ckan/default/resources/ebe/b92/fe-424c-41d1-aacf-288e91049dc9',
#                                         'cache_url': 'https://data.gov.ua/dataset/0ffd8b75-0628-48cc-952a-9302f9799ec0/resource/ebeb92fe-424c-41d1-aacf-288e91049dc9/download/tz_opendata_z01012020_po01072020.zip',
#                                         'created': '2020-04-28T02:45:22.417070',
#                                         'etag': None,
#                                         'failure_count': 0,
#                                         'first_failure': None,
#                                         'hash': 'd240fbd0bcd8c04749490cf1c7f448d60d771a95',
#                                         'is_broken': False,
#                                         'is_broken_printable': 'Downloaded OK',
#                                         'last_modified': None,
#                                         'last_success': '2020-07-14T13:01:23.283810',
#                                         'mimetype': 'application/zip',
#                                         'reason': '',
#                                         'resource_timestamp': '2020-07-01T10:19:00.839595',
#                                         'size': 27947539,
#                                         'status': 'Archived successfully',
#                                         'status_id': 0,
#                                         'updated': '2020-07-14T13:01:23.283810',
#                                         'url_redirected_to': 'https://data.gov.ua/dataset/0ffd8b75-0628-48cc-952a-9302f9799ec0/resource/ebeb92fe-424c-41d1-aacf-288e91049dc9/download/tz_opendata_z01012020_po01072020.zip'},
#                            'cache_last_updated': None,
#                            'cache_url': None,
#                            'created': '2020-02-04T16:13:55.936851',
#                            'datastore_active': False,
#                            'description': 'Дані щодо транспортних засобів за '
#                                           '2020 рік',
#                            'file_hash_sum': 'ddecf604fe6a67514e1bab50b4aea6c7',
#                            'format': 'csv zip',
#                            'hash': '',
#                            'id': 'ebeb92fe-424c-41d1-aacf-288e91049dc9',
#                            'last_modified': '2021-01-04T07:17:12.445231',
#                            'mimetype': 'application/zip',
#                            'mimetype_inner': None,
#                            'name': 'reestrTZ2020',
#                            'package_id': '0ffd8b75-0628-48cc-952a-9302f9799ec0',
#                            'position': 7,
#                            'qa': {'archival_timestamp': '2020-06-29T13:12:26.821393',
#                                   'created': '2020-03-29T20:52:36.624756',
#                                   'format': 'CSV',
#                                   'openness_score': 3,
#                                   'openness_score_reason': 'Content of file '
#                                                            'appeared to be '
#                                                            'format "%s" which '
#                                                            'receives openness '
#                                                            'score: %s.',
#                                   'openness_score_reason_args': '[["CSV", 3]]',
#                                   'resource_timestamp': None,
#                                   'updated': '2020-07-12T20:25:50.175167'},
#                            'resource_type': None,
#                            'revision_id': '611bb3f5-05ea-41bd-916b-b4996c7dbaaf',
#                            'size': 70487994,
#                            'state': 'active',
#                            'url': 'https://data.gov.ua/dataset/0ffd8b75-0628-48cc-952a-9302f9799ec0/resource/ebeb92fe-424c-41d1-aacf-288e91049dc9/download/tz_opendata_z01012020_po01012021.zip',
#                            'url_type': 'upload'},
#                           {'archiver': "{'is_broken_printable': 'Downloaded "
#                                        "OK', 'updated': "
#                                        "'2020-01-17T12:16:28.977273', "
#                                        "'cache_filepath': "
#                                        "u'/mnt/storage/ckan/default/resources/af5/330/21-51af-4106-a761-de35f671226b', "
#                                        "'last_success': "
#                                        "'2020-01-17T12:16:28.977273', 'size': "
#                                        "60928L, 'is_broken': False, "
#                                        "'failure_count': 0, 'etag': None, "
#                                        "'status': 'Archived successfully', "
#                                        "'url_redirected_to': "
#                                        "u'https://data.gov.ua/dataset/1740ad39-7e3b-4a3e-a7d1-cb3ff65e662d/resource/af533021-51af-4106-a761-de35f671226b/download/zvit-pro-finansovi-rezultati-forma-2-ds.xls', "
#                                        "'hash': "
#                                        "u'431968e893e6d0e4afc53d012aa8d11d2e348646', "
#                                        "'status_id': 0, 'reason': u'', "
#                                        "'last_modified': None, "
#                                        "'resource_timestamp': "
#                                        "'2019-12-30T12:46:51.795959', "
#                                        "'mimetype': "
#                                        "u'application/vnd.ms-excel', "
#                                        "'cache_url': "
#                                        "u'https://data.gov.ua/dataset/1740ad39-7e3b-4a3e-a7d1-cb3ff65e662d/resource/af533021-51af-4106-a761-de35f671226b/download/zvit-pro-finansovi-rezultati-forma-2-ds.xls', "
#                                        "'created': "
#                                        "'2019-06-20T00:11:58.278367', "
#                                        "'first_failure': None}",
#                            'cache_last_updated': None,
#                            'cache_url': None,
#                            'created': '2021-02-01T15:20:40.005061',
#                            'datastore_active': False,
#                            'description': 'Дані щодо транспортних засобів '
#                                           'станом на 01 квітня 2021',
#                            'file_hash_sum': 'ddecf604fe6a67514e1bab50b4aea6c7',
#                            'format': 'csv zip',
#                            'hash': '',
#                            'id': 'c5cb530d-0533-40be-b9ad-f03e06c94b10',
#                            'last_modified': '2021-04-01T13:58:04.660556',
#                            'mimetype': 'application/zip',
#                            'mimetype_inner': None,
#                            'name': 'reestrTZ2021',
#                            'package_id': '0ffd8b75-0628-48cc-952a-9302f9799ec0',
#                            'position': 8,
#                            'qa': "{'updated': '2020-03-09T19:02:07.061497', "
#                                  "'openness_score': 2, 'archival_timestamp': "
#                                  "'2020-01-17T12:16:28.977273', 'format': "
#                                  "u'XLS', 'openness_score_reason_args': "
#                                  'u\'[["XLS", 2]]\', \'created\': '
#                                  "'2019-06-20T03:40:14.406802', "
#                                  "'resource_timestamp': None, "
#                                  "'openness_score_reason': u'Content of file "
#                                  'appeared to be format "%s" which receives '
#                                  "openness score: %s.'}",
#                            'resource_type': None,
#                            'revision_id': '74150342-9bb7-44d0-858b-52c4a64fb11c',
#                            'size': 16453200,
#                            'state': 'active',
#                            'url': 'https://data.gov.ua/dataset/0ffd8b75-0628-48cc-952a-9302f9799ec0/resource/c5cb530d-0533-40be-b9ad-f03e06c94b10/download/tz_opendata_z01012021_po01042021.zip',
#                            'url_type': 'upload'}],
#             'revision_id': '5f1d8b0e-096a-46c9-8702-52cc527d0225',
#             'state': 'active',
#             'tag_string': 'транспортні,автомобілі,власники,реєстр,засоби,автомобіль,тз,колісні,власник',
#             'tags': [{'display_name': 'автомобіль',
#                       'id': 'dc30f9c1-8915-4d6f-9a25-2af2acfca17b',
#                       'name': 'автомобіль',
#                       'state': 'active',
#                       'vocabulary_id': None},
#                      {'display_name': 'автомобілі',
#                       'id': '6f8e8820-1183-4743-945f-d45edcc73ea5',
#                       'name': 'автомобілі',
#                       'state': 'active',
#                       'vocabulary_id': None},
#                      {'display_name': 'власник',
#                       'id': '4697cb85-42cb-4358-8152-73b8771eabd7',
#                       'name': 'власник',
#                       'state': 'active',
#                       'vocabulary_id': None},
#                      {'display_name': 'власники',
#                       'id': '4a407aec-194e-411e-b1ea-6e99c30eb838',
#                       'name': 'власники',
#                       'state': 'active',
#                       'vocabulary_id': None},
#                      {'display_name': 'засоби',
#                       'id': 'bad83b2a-4968-49b6-9be3-6054c1bde548',
#                       'name': 'засоби',
#                       'state': 'active',
#                       'vocabulary_id': None},
#                      {'display_name': 'колісні',
#                       'id': '578755fc-f868-465d-9a15-536a3a6f3187',
#                       'name': 'колісні',
#                       'state': 'active',
#                       'vocabulary_id': None},
#                      {'display_name': 'реєстр',
#                       'id': 'cb838029-a0c8-4e35-9e5d-9d4155ceae1d',
#                       'name': 'реєстр',
#                       'state': 'active',
#                       'vocabulary_id': None},
#                      {'display_name': 'тз',
#                       'id': '7ab9a201-77d7-4cba-8448-2ab82332f56b',
#                       'name': 'тз',
#                       'state': 'active',
#                       'vocabulary_id': None},
#                      {'display_name': 'транспортні',
#                       'id': '7fd5472e-b17f-4d75-b2c9-4012b7607f45',
#                       'name': 'транспортні',
#                       'state': 'active',
#                       'vocabulary_id': None}],
#             'title': 'Відомості про транспортні засоби та їх власників',
#             'type': 'dataset',
#             'update_frequency': 'once a month',
#             'url': None,
#             'version': '1.0'},
#  'success': True}

# %% [markdown]
# Нам треба знайти дані із атрибутом "url_redirected_to" повний шлях: "["result"]["resources"][_порядковий номер ресурсу_]["url"]"
# Отримуємо дані за допомогою циклу, яким перебираємо всі посилання на ресурси у наборі.

# %%
for i in response["result"]["resources"]:
    print(i["description"], " :", i["url"])
# Out:
# Дані щодо транспортних засобів за 2018 рік  : https://data.gov.ua/dataset/0ffd8b75-0628-48cc-952a-9302f9799ec0/resource/01323740-88df-46c2-b06e-fbb58c89fe17/download/tz_opendata_z01012018_po01012019.zip
# Дані щодо транспортних засобів за 2017 рік  : https://data.gov.ua/dataset/0ffd8b75-0628-48cc-952a-9302f9799ec0/resource/9ce32352-bd11-4324-a2b4-5addbd228b1b/download/tz_opendata_z01012017_po31122017.zip
# Дані щодо транспортних засобів за 2016 рік  : https://data.gov.ua/dataset/0ffd8b75-0628-48cc-952a-9302f9799ec0/resource/7bdc2a1b-5399-4ab0-97e0-633e68837b04/download/tz_opendata_z01012016_po31122016.zip
# Дані щодо транспортних засобів за 2015 рік  : https://data.gov.ua/dataset/0ffd8b75-0628-48cc-952a-9302f9799ec0/resource/09c606dc-d740-40db-96f0-e679eeca6ace/download/tz_opendata_z01012015_po31122015.zip
# Дані щодо транспортних засобів за 2014 рік  : https://data.gov.ua/dataset/0ffd8b75-0628-48cc-952a-9302f9799ec0/resource/80a115ae-61df-4a13-8771-36c2826268df/download/tz_opendata_z01012014_po31122014.zip
# Дані щодо транспортних засобів за 2013 рік  : https://data.gov.ua/dataset/0ffd8b75-0628-48cc-952a-9302f9799ec0/resource/86a9548b-8323-4fa2-972e-0692edf6959f/download/tz_opendata_z01012013_po31122013.zip
# Дані щодо транспортних засобів за 2019 рік  : https://data.gov.ua/dataset/0ffd8b75-0628-48cc-952a-9302f9799ec0/resource/7a58e8f7-9323-47d4-a21d-19486e014eb4/download/tz_opendata_z01012019_po01012020.zip
# Дані щодо транспортних засобів за 2020 рік  : https://data.gov.ua/dataset/0ffd8b75-0628-48cc-952a-9302f9799ec0/resource/ebeb92fe-424c-41d1-aacf-288e91049dc9/download/tz_opendata_z01012020_po01012021.zip
# Дані щодо транспортних засобів станом на 01 квітня 2021  : https://data.gov.ua/dataset/0ffd8b75-0628-48cc-952a-9302f9799ec0/resource/c5cb530d-0533-40be-b9ad-f03e06c94b10/download/tz_opendata_z01012021_po01042021.zip

# %%
urls = [i["url"] for i in response["result"]["resources"]]
urls
# Out:
# ['https://data.gov.ua/dataset/0ffd8b75-0628-48cc-952a-9302f9799ec0/resource/01323740-88df-46c2-b06e-fbb58c89fe17/download/tz_opendata_z01012018_po01012019.zip',
#  'https://data.gov.ua/dataset/0ffd8b75-0628-48cc-952a-9302f9799ec0/resource/9ce32352-bd11-4324-a2b4-5addbd228b1b/download/tz_opendata_z01012017_po31122017.zip',
#  'https://data.gov.ua/dataset/0ffd8b75-0628-48cc-952a-9302f9799ec0/resource/7bdc2a1b-5399-4ab0-97e0-633e68837b04/download/tz_opendata_z01012016_po31122016.zip',
#  'https://data.gov.ua/dataset/0ffd8b75-0628-48cc-952a-9302f9799ec0/resource/09c606dc-d740-40db-96f0-e679eeca6ace/download/tz_opendata_z01012015_po31122015.zip',
#  'https://data.gov.ua/dataset/0ffd8b75-0628-48cc-952a-9302f9799ec0/resource/80a115ae-61df-4a13-8771-36c2826268df/download/tz_opendata_z01012014_po31122014.zip',
#  'https://data.gov.ua/dataset/0ffd8b75-0628-48cc-952a-9302f9799ec0/resource/86a9548b-8323-4fa2-972e-0692edf6959f/download/tz_opendata_z01012013_po31122013.zip',
#  'https://data.gov.ua/dataset/0ffd8b75-0628-48cc-952a-9302f9799ec0/resource/7a58e8f7-9323-47d4-a21d-19486e014eb4/download/tz_opendata_z01012019_po01012020.zip',
#  'https://data.gov.ua/dataset/0ffd8b75-0628-48cc-952a-9302f9799ec0/resource/ebeb92fe-424c-41d1-aacf-288e91049dc9/download/tz_opendata_z01012020_po01012021.zip',
#  'https://data.gov.ua/dataset/0ffd8b75-0628-48cc-952a-9302f9799ec0/resource/c5cb530d-0533-40be-b9ad-f03e06c94b10/download/tz_opendata_z01012021_po01042021.zip']

# %%
os.mkdir("data")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-9-ad3f46ea0811> in <module>
# ----> 1 os.mkdir("data")
#
# FileExistsError: [WinError 183] Невозможно создать файл, так как он уже существует: 'data'

# %%
for url in urls:
    response = requests.get(url)
    zip_data = io.BytesIO(response.content)
    # розпаковуємо архів із даними
    print("zip_data = io.BytesIO(rs.content)")
    with zipfile.ZipFile(zip_data) as zip_file:
        print("zip_file.extractall")
        zip_file.extractall("data")
# Out:
# zip_data = io.BytesIO(rs.content)
# zip_file.extractall
# zip_data = io.BytesIO(rs.content)
# zip_file.extractall
# zip_data = io.BytesIO(rs.content)
# zip_file.extractall
# zip_data = io.BytesIO(rs.content)
# zip_file.extractall
# zip_data = io.BytesIO(rs.content)
# zip_file.extractall
# zip_data = io.BytesIO(rs.content)
# zip_file.extractall
# zip_data = io.BytesIO(rs.content)
# zip_file.extractall
# zip_data = io.BytesIO(rs.content)
# zip_file.extractall
# zip_data = io.BytesIO(rs.content)
# zip_file.extractall

# %% [markdown]
# Отримуємо перелік всіх файлів в директорії

# %%
directory = os.listdir("data")
directory
# Out:
# ['tz_opendata_z01012013_po31122013.csv',
#  'tz_opendata_z01012014_po31122014.csv',
#  'tz_opendata_z01012015_po31122015.csv',
#  'tz_opendata_z01012016_po31122016.csv',
#  'tz_opendata_z01012017_po31122017.csv',
#  'tz_opendata_z01012018_po01012019.csv',
#  'tz_opendata_z01012019_po01012020.csv',
#  'tz_opendata_z01012020_po01012021.csv',
#  'tz_opendata_z01012021_po01042021.csv']

# %% [markdown]
# # Підвантажєння та підготовка даних

# %% [markdown]
# ## Перекодовуємо інформацію про області та сервісні центри

# %%
# тестуємо завантаження даних
data = pd.read_csv("data/tz_opendata_z01012013_po31122013.csv", error_bad_lines = False, sep = ";", )

# %%
data = pd.DataFrame()
for f in directory:
    table = pd.read_csv("data/"+ str(f), error_bad_lines = False, sep = ";")
    data = pd.concat([data, table])
data

# %%
data.columns

# %%
# правильний спосіб завантаження даних в pandas, якщов они зберігаються у кількох таблицях
data = pd.DataFrame()
for f in directory:
    table = pd.read_csv("data/"+ str(f), error_bad_lines = False, sep = ";")
    table.columns = table.columns.str.lower() #у деяких старих наборах даних заголовки колонок великими літерами
    data = pd.concat([data, table])
data
# Out:
# c:\users\dhuba\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (17) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# c:\users\dhuba\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (16,17) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#        person  reg_addr_koatuu  oper_code  \
# 0           P     5.101370e+08         40
# 1           P     5.110137e+09        230
# 2           P     2.310137e+09         40
# 3           P     6.110100e+09        400
# 4           P     6.110100e+09        400
# ...       ...              ...        ...
# 443461      P              NaN         71
# 443462      P     5.104000e+08        308
# 443463      P     5.101000e+08         71
# 443464      P              NaN        308
# 443465      P     7.410137e+09        308
#
#                                                 oper_name       d_reg  \
# 0       40 - ВТОРИННА РЕЄСТРАЦІЯ ТЗ, ПРИДБАНОГО В ТОРГ...  2013-01-16
# 1       230 -  ВИДАЧА СВ. ПРО РЕЄСТР ДЛЯ ПОЇЗДКИ ЗА КО...  2013-08-29
# 2       40 - ВТОРИННА РЕЄСТРАЦІЯ ТЗ, ПРИДБАНОГО В ТОРГ...  2013-02-02
# 3       400 - ПЕРЕРЕЄСТРАЦIЯ ПРИ ПЕРЕОБЛАДНАННI БЕЗ ЗА...  2013-01-26
# 4       400 - ПЕРЕРЕЄСТРАЦIЯ ПРИ ПЕРЕОБЛАДНАННI БЕЗ ЗА...  2013-01-05
# ...                                                   ...         ...
# 443461  РЕЄСТРАЦІЯ ТЗ ПРИВЕЗЕНОГО З-ЗА КОРДОНУ ПО ПОСВ...  05.03.2021
# 443462  ПЕРЕРЕЄСТРАЦІЯ НА НОВОГО ВЛАСНИКА ЗА ДОГ. КУПI...  16.03.2021
# 443463  РЕЄСТРАЦІЯ ТЗ ПРИВЕЗЕНОГО З-ЗА КОРДОНУ ПО ПОСВ...  05.03.2021
# 443464  ПЕРЕРЕЄСТРАЦІЯ НА НОВОГО ВЛАСНИКА ЗА ДОГ. КУПI...  30.03.2021
# 443465  ПЕРЕРЕЄСТРАЦІЯ НА НОВОГО ВЛАСНИКА ЗА ДОГ. КУПI...  25.03.2021
#
#         dep_code                                                dep  \
# 0        1305301  ВІННИЦЬКИЙ  ВРЕР УДАІ УМВС УКРАЇНИ У ВІННИЦЬКІ...
# 1           5146                                         Центр 5146
# 2           1242                                         Центр 1242
# 3           6141                                         Центр 6141
# 4           6141                                         Центр 6141
# ...          ...                                                ...
# 443461     12373                                           ТСЦ 6843
# 443462     12231                                           ТСЦ 0543
# 443463     12229                                           ТСЦ 0541
# 443464     12250                                           ТСЦ 1443
# 443465     13960                                           ТСЦ 8048
#
#                                   brand             model  make_year   color  \
# 0                    SSANG YONG  REXTON            REXTON       2007  ЧОРНИЙ
# 1                        TOYOTA  PREVIA            PREVIA       2007   СІРИЙ
# 2                        SKODA  OCTAVIA           OCTAVIA       2011   БІЛИЙ
# 3                        CITROEN  JUMPY             JUMPY       2008   БІЛИЙ
# 4       MERCEDES-BENZ  SPRINTER 313 CDI  SPRINTER 313 CDI       2005   БІЛИЙ
# ...                                 ...               ...        ...     ...
# 443461                            SKODA     OCTAVIA COMBI       2002   СІРИЙ
# 443462                          HYUNDAI          SANTA FE       2007  ЧОРНИЙ
# 443463                          HYUNDAI          SANTA FE       2007  ЧОРНИЙ
# 443464                             FORD             C-MAX       2014   БІЛИЙ
# 443465                       VOLKSWAGEN            TOURAN       2004   СІРИЙ
#
#             kind            body    purpose                fuel  capacity  \
# 0       ЛЕГКОВИЙ     УНІВЕРСАЛ-B  ЗАГАЛЬНИЙ     ДИЗЕЛЬНЕ ПАЛИВО    2696.0
# 1       ЛЕГКОВИЙ     УНІВЕРСАЛ-B  ЗАГАЛЬНИЙ              БЕНЗИН    2362.0
# 2       ЛЕГКОВИЙ       ХЕТЧБЕК-В  ЗАГАЛЬНИЙ              БЕНЗИН    1595.0
# 3       ЛЕГКОВИЙ  ПАСАЖИРСЬКИЙ-B  ЗАГАЛЬНИЙ     ДИЗЕЛЬНЕ ПАЛИВО    1560.0
# 4       ЛЕГКОВИЙ  ПАСАЖИРСЬКИЙ-B  ЗАГАЛЬНИЙ     ДИЗЕЛЬНЕ ПАЛИВО    2148.0
# ...          ...             ...        ...                 ...       ...
# 443461  ЛЕГКОВИЙ       УНІВЕРСАЛ  ЗАГАЛЬНИЙ              БЕНЗИН    1595.0
# 443462  ЛЕГКОВИЙ       УНІВЕРСАЛ  ЗАГАЛЬНИЙ     ДИЗЕЛЬНЕ ПАЛИВО    2188.0
# 443463  ЛЕГКОВИЙ       УНІВЕРСАЛ  ЗАГАЛЬНИЙ     ДИЗЕЛЬНЕ ПАЛИВО    2188.0
# 443464  ЛЕГКОВИЙ       УНІВЕРСАЛ  ЗАГАЛЬНИЙ  ЕЛЕКТРО АБО БЕНЗИН    2000.0
# 443465  ЛЕГКОВИЙ       УНІВЕРСАЛ  ЗАГАЛЬНИЙ              БЕНЗИН    1595.0
#
#        own_weight total_weight n_reg_new
# 0          2069.0       2550.0  АВ1923ВТ
# 1          1720.0       2450.0  ВН8542СО
# 2          1245.0       1720.0  АР6199СІ
# 3          1736.0       2661.0  ВО5930ВА
# 4          1995.0       3500.0  ВО5562ВА
# ...           ...          ...       ...
# 443461       1295         1805  ВХ8612ЕО
# 443462       2030         2570  АВ5529НО
# 443463       2030         2570  АВ0875НТ
# 443464       1674         2250  АН4178ОН
# 443465       1502         2090  СВ0975СХ
#
# [13363212 rows x 19 columns]

# %%
data.columns

# %% [markdown]
# Дані із кодами КОАТУУ - частково не заповнені, ми не хочемо втратити інформацію про жодну зареєстровану дію, тому ми не будемо використовувати дані із атрибуту data["reg_addr_koatuu"], натомість ми геокодуємо дані з інформації про орган, який здійснював реєстраційні дії. Але ці дані доволі брудні, також під час формування набору у 2013 - 2015 роках проховодилась реформа, що призвело до того, що ми маємо інформацію про різні орагни реєстраці. Сучасні органи кодуються у форматі ТСЦ ххуу - де хх - код регіону, а уу - унікальний код сервісного центру.
# Завантажимо таблицю, яка містить інформацію про сучасну прив'язку ТСЦ до областей та виведемо її, для цього треба налаштувати Pandas

# %%
# встановлення обмеження на кількість відображених рядків
pd.set_option('display.max_rows', 160)
 
# скидання обмеження на кількість відображених атрибутів
pd.set_option('display.max_columns', None)
 
# встановлення обмеження на кількість відображених символів в комірці
pd.set_option('display.max_colwidth', 25)

# %%
# читаємо таблицю
deps = pd.read_excel("dep.xlsx")

# %%
# виводимо її на екран
deps

# %%
# дублюємо колонку із даними про департаменти для подальшого кодування регіонів
data["region"] = data["dep"]

# %%
# зводимо все до нижнього регістру
data["region"] = data["region"].str.lower()

# стандартизуємо дані із назвами сервісних центрів

data["region"] = data["region"].str.replace(r"\((\d{4})\).*", r"тсц \1", regex=True)
# Для быльшої зрозумілості виокремити області вирішив через окремі ітерації
data["region"] = data["region"].str.replace(r".*макарі.*|.*київсь.*", r"київська", regex=True)
data["region"] = data["region"].str.replace(r".*чернівець.*", r"чернівецька", regex=True)
data["region"] = data["region"].str.replace(r".*херсон.*", r"херсонська", regex=True)
data["region"] = data["region"].str.replace(r".*мог-подільськ.*|.*липовец.*|.*ямпіл.*|.*калинівс.*|.*тульчин.*|.*козятин.*|.*вінниць.*|.*жмерин.*|.*берша.*|.*крижо.*|.*хмільн.*|.*гайсин.*|.*немирів.*", r"вінницька", regex=True)
data["region"] = data["region"].str.replace(r".*донець.*", r"донецька", regex=True)
data["region"] = data["region"].str.replace(r".*тернопіль.*", r"тернопільська", regex=True)
data["region"] = data["region"].str.replace(r".*запорі.*", r"запорізька", regex=True)
data["region"] = data["region"].str.replace(r".*волин.*|.*горохів.*|.*луцьк.*|.*ковел.*|.*ківер.*|.*любом.*|.*кашир.*", r"волинська", regex=True)
data["region"] = data["region"].str.replace(r".*дніпропе.*", r"дніпропетровська", regex=True)
data["region"] = data["region"].str.replace(r".*полтав.*", r"полтавська", regex=True)
data["region"] = data["region"].str.replace(r".*чернігів.*", r"чернігівська", regex=True)
data["region"] = data["region"].str.replace(r".*миколаїв.*", r"миколаївська", regex=True)
data["region"] = data["region"].str.replace(r".*житомир.*|.*овруц.*|.*овруч.*|.*коростен.*|.*чудні.*|.*попільня.*|.*бердичі.*|.*радомиш.*", r"житомирська", regex=True)
data["region"] = data["region"].str.replace(r".*львів.*", r"львівська", regex=True)
data["region"] = data["region"].str.replace(r".*черкас.*", r"черкаська", regex=True)
data["region"] = data["region"].str.replace(r".*івано.*", r"івано-Франківська", regex=True)
data["region"] = data["region"].str.replace(r".*харків.*", r"харківська", regex=True)
data["region"] = data["region"].str.replace(r".*рівне.*", r"рівненська", regex=True)
data["region"] = data["region"].str.replace(r".*сум.*", r"сумська", regex=True)
data["region"] = data["region"].str.replace(r".*нетіши.*", r"хмельницька", regex=True)
data["region"] = data["region"].str.replace(r".*іршав.*|.*міжгірсь.*|.*виноградів.*|.*тячів.*|.*сваляв.*|.*берегів.*|.*берегов.*|.*рахів.*|.*ужгород.*|.*мукаче.*|.*мукачів.*|.*хуст.*", r"закарпатська", regex=True)
data["region"] = data["region"].str.replace(r".*м\. кіровсь.*|.*луганс.*|.*лутуг.*", r"луганська", regex=True)
data["region"] = data["region"].str.replace(r".*м\. київ.*|.*києв.*|.*головний.*|.*міністерство.*", r"київ", regex=True)
data["region"] = data["region"].str.replace(r".*крим.*|.*євпаторія.*|.*судак.*|.*армян.*|.*сімферополь.*|.*симферопіль.*|.*бахчисарай.*", r"крим", regex=True)
data["region"] = data["region"].str.replace(r"центр|тсц даі", r"тсц", regex=True)

# %%
# перевіряємо унікальні значення після використання регулярних виразів
pp(data["region"].unique())
# Out:
# array(['вінницька', 'одеська', 'дніпропетровська', 'тернопільська',
#        'київ', 'чернівецька', 'луганська', 'донецька', 'харківська',
#        'львівська', 'миколаївська', 'запорізька', 'житомирська',
#        'херсонська', 'рівненська', 'хмельницька', 'сумська', 'полтавська',
#        'крим', 'київська', 'волинська', 'кіровоградська', 'черкаська',
#        'тсц 1408', 'закарпатська', 'тсц 1401', 'івано-Франківська',
#        'тсц 7401', 'тсц 1402', 'тсц 1403', 'тсц 1416', 'тсц 1411',
#        'тсц 1418', 'тсц 1412', 'тсц 7404', 'тсц 7402', 'тсц 7406',
#        'тсц 1413', 'тсц 1409', 'тсц 1414', 'тсц 1420', 'тсц 1404',
#        'тсц 1405', 'тсц 1406', 'тсц 1419', 'тсц 1410', 'тсц 1417',
#        'тсц 7403', 'тсц 1415', 'тсц 7405', 'тсц 1421', 'тсц 1407',
#        'тсц 1422', 'овруцьке врер', 'мвс україни', 'чернігівська'],
#       dtype=object)

# %% [markdown]
# Кодуємо області в тіх записах де відомі номери сервісних центрів

# %%
data["region"] = data["region"].str.lower()
data["region"] = data["region"].str.replace(r"тсц 05.*", r"вінницька", regex=True)
data["region"] = data["region"].str.replace(r"тсц 07.*", r"волинська", regex=True)
data["region"] = data["region"].str.replace(r"тсц 12.*", r"дніпропетровська", regex=True)
data["region"] = data["region"].str.replace(r"тсц 14.*", r"донецька", regex=True)
data["region"] = data["region"].str.replace(r"тсц 18.*", r"житомирська", regex=True)
data["region"] = data["region"].str.replace(r"тсц 21.*", r"закарпатська", regex=True)
data["region"] = data["region"].str.replace(r"тсц 23.*", r"запорізька", regex=True)
data["region"] = data["region"].str.replace(r"тсц 26.*", r"івано-Франківська", regex=True)
data["region"] = data["region"].str.replace(r"тсц 32.*", r"київська", regex=True)
data["region"] = data["region"].str.replace(r"тсц 35.*", r"кіровоградська", regex=True)
data["region"] = data["region"].str.replace(r"тсц 44.*", r"луганська", regex=True)
data["region"] = data["region"].str.replace(r"тсц 46.*", r"львівська", regex=True)
data["region"] = data["region"].str.replace(r"тсц 48.*", r"миколаївська", regex=True)
data["region"] = data["region"].str.replace(r"тсц 51.*", r"одеська", regex=True)
data["region"] = data["region"].str.replace(r"тсц 53.*", r"полтавська", regex=True)
data["region"] = data["region"].str.replace(r"тсц 56.*", r"рівненська", regex=True)
data["region"] = data["region"].str.replace(r"тсц 59.*", r"сумська", regex=True)
data["region"] = data["region"].str.replace(r"тсц 61.*", r"тернопільська", regex=True)
data["region"] = data["region"].str.replace(r"тсц 63.*", r"харківська", regex=True)
data["region"] = data["region"].str.replace(r"тсц 65.*", r"херсонська", regex=True)
data["region"] = data["region"].str.replace(r"тсц 68.*", r"хмельницька", regex=True)
data["region"] = data["region"].str.replace(r"тсц 71.*", r"черкаська", regex=True)
data["region"] = data["region"].str.replace(r"тсц 73.*", r"чернівецька", regex=True)
data["region"] = data["region"].str.replace(r"тсц 74.*", r"чернігівська", regex=True)
data["region"] = data["region"].str.replace(r"тсц 80.*", r"київ", regex=True)
data["region"] = data["region"].str.replace(r"тсц 85.*|тсц 01.*", r"крим", regex=True) # кодуємо дані спільно для Криму та Сімферополя
data["region"] = data["region"].str.replace(r"мвс україни.*", r"київ", regex=True)

# %%
# Перевіряємо чи все ок із регіонами
data["region"].unique()
# Out:
# array(['вінницька', 'одеська', 'дніпропетровська', 'тернопільська',
#        'київ', 'чернівецька', 'луганська', 'донецька', 'харківська',
#        'львівська', 'миколаївська', 'запорізька', 'житомирська',
#        'херсонська', 'рівненська', 'хмельницька', 'сумська', 'полтавська',
#        'крим', 'київська', 'волинська', 'кіровоградська', 'черкаська',
#        'закарпатська', 'івано-франківська', 'чернігівська'], dtype=object)

# %%
# Зберігаємо дані у файл
data.to_csv("data_normalize.csv")

# %% [markdown]
# ## Підвантажуємо "чистий" набір із даними

# %%
# Завантажуємо дані із файлу
data = pd.read_csv("data_normalize.csv", low_memory = False)
data.head()
# Out:
#    Unnamed: 0 person  reg_addr_koatuu  oper_code  \
# 0           0      P     5.101370e+08         40
# 1           1      P     5.110137e+09        230
# 2           2      P     2.310137e+09         40
# 3           3      P     6.110100e+09        400
# 4           4      P     6.110100e+09        400
#
#                                            oper_name       d_reg  dep_code  \
# 0  40 - ВТОРИННА РЕЄСТРАЦІЯ ТЗ, ПРИДБАНОГО В ТОРГ...  2013-01-16   1305301
# 1  230 -  ВИДАЧА СВ. ПРО РЕЄСТР ДЛЯ ПОЇЗДКИ ЗА КО...  2013-08-29      5146
# 2  40 - ВТОРИННА РЕЄСТРАЦІЯ ТЗ, ПРИДБАНОГО В ТОРГ...  2013-02-02      1242
# 3  400 - ПЕРЕРЕЄСТРАЦIЯ ПРИ ПЕРЕОБЛАДНАННI БЕЗ ЗА...  2013-01-26      6141
# 4  400 - ПЕРЕРЕЄСТРАЦIЯ ПРИ ПЕРЕОБЛАДНАННI БЕЗ ЗА...  2013-01-05      6141
#
#                                                  dep  \
# 0  ВІННИЦЬКИЙ  ВРЕР УДАІ УМВС УКРАЇНИ У ВІННИЦЬКІ...
# 1                                         Центр 5146
# 2                                         Центр 1242
# 3                                         Центр 6141
# 4                                         Центр 6141
#
#                              brand             model  ...   color      kind  \
# 0               SSANG YONG  REXTON            REXTON  ...  ЧОРНИЙ  ЛЕГКОВИЙ
# 1                   TOYOTA  PREVIA            PREVIA  ...   СІРИЙ  ЛЕГКОВИЙ
# 2                   SKODA  OCTAVIA           OCTAVIA  ...   БІЛИЙ  ЛЕГКОВИЙ
# 3                   CITROEN  JUMPY             JUMPY  ...   БІЛИЙ  ЛЕГКОВИЙ
# 4  MERCEDES-BENZ  SPRINTER 313 CDI  SPRINTER 313 CDI  ...   БІЛИЙ  ЛЕГКОВИЙ
#
#              body    purpose             fuel capacity  own_weight  \
# 0     УНІВЕРСАЛ-B  ЗАГАЛЬНИЙ  ДИЗЕЛЬНЕ ПАЛИВО   2696.0      2069.0
# 1     УНІВЕРСАЛ-B  ЗАГАЛЬНИЙ           БЕНЗИН   2362.0      1720.0
# 2       ХЕТЧБЕК-В  ЗАГАЛЬНИЙ           БЕНЗИН   1595.0      1245.0
# 3  ПАСАЖИРСЬКИЙ-B  ЗАГАЛЬНИЙ  ДИЗЕЛЬНЕ ПАЛИВО   1560.0      1736.0
# 4  ПАСАЖИРСЬКИЙ-B  ЗАГАЛЬНИЙ  ДИЗЕЛЬНЕ ПАЛИВО   2148.0      1995.0
#
#   total_weight n_reg_new            region
# 0       2550.0  АВ1923ВТ         вінницька
# 1       2450.0  ВН8542СО           одеська
# 2       1720.0  АР6199СІ  дніпропетровська
# 3       2661.0  ВО5930ВА     тернопільська
# 4       3500.0  ВО5562ВА     тернопільська
#
# [5 rows x 21 columns]

# %% [markdown]
# Визначаємо пропущені значення - будуємо теплокарту пропущених значень.

# %%
cols = data.columns
# визначаємо кольори
# жовтий - пропущені значення, синій - дійсні значення
colours = ['#000099', '#ffff00'] 
sns.heatmap(data[cols].isnull(), cmap=sns.color_palette(colours))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Переглядаємо статистику значень

# %%
for col in data.columns:
    pct_missing = np.mean(data[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# index - 0%
# Unnamed: 0 - 0%
# person - 0%
# reg_addr_koatuu - 4%
# oper_code - 0%
# oper_name - 0%
# d_reg - 0%
# dep_code - 0%
# dep - 0%
# brand - 0%
# model - 0%
# make_year - 0%
# color - 0%
# kind - 0%
# body - 0%
# purpose - 0%
# fuel - 5%
# capacity - 6%
# own_weight - 1%
# total_weight - 0%
# n_reg_new - 1%
# region - 0%
# brand_new - 0%
# brand_model - 0%

# %% [markdown]
# Будуємо гістограму пропущених значень

# %%
# будуємо індикатор для пропущених значень
for col in data.columns:
    missing = data[col].isnull()
    num_missing = np.sum(missing)
    
    if num_missing > 0:  
        print('created missing indicator for: {}'.format(col))
        data['{}_ismissing'.format(col)] = missing


# будуємо гістограму на основі індикатора
ismissing_cols = [col for col in data.columns if 'ismissing' in col]
data['num_missing'] = data[ismissing_cols].sum(axis=1)

data['num_missing'].value_counts().reset_index().sort_values(by='index').plot.bar(x='index', y='num_missing')
# Out:
# created missing indicator for: reg_addr_koatuu
# created missing indicator for: fuel
# created missing indicator for: capacity
# created missing indicator for: own_weight
# created missing indicator for: total_weight
# created missing indicator for: n_reg_new
# <AxesSubplot:xlabel='index'>

# %% [markdown]
# Продовжуємо досліджувати дані

# %%
#Перевіряємо види реєстрацій автомобілів
data["oper_name"].unique()
# Out:
# array(['40 - ВТОРИННА РЕЄСТРАЦІЯ ТЗ, ПРИДБАНОГО В ТОРГОВЕЛЬНІЙ ОРГАНІЗАЦІЇ',
#        '230 -  ВИДАЧА СВ. ПРО РЕЄСТР ДЛЯ ПОЇЗДКИ ЗА КОРДОН ПО ДОРУЧ',
#        '400 - ПЕРЕРЕЄСТРАЦIЯ ПРИ ПЕРЕОБЛАДНАННI БЕЗ ЗАМIНИ НОМЕРНИХ АГРЕГ.',
#        '30 - ПЕРВИННА РЕЄСТРАЦІЯ ТЗ ДЛЯ ІНДИВ. ВЛАСНИКА',
#        '440 - ПЕРЕРЕЄСТРАЦIЯ ПРИ ВТРАТІ СВIДОЦТВА ПРО РЕЄСТРАЦIЮ',
#        '430 - ПЕРЕРЕЄСТРАЦІЯ ПРИ ЗАМІНІ СВІДОЦТВА ПРО РЕЄСТРАЦІЮ',
#        '100 - ПЕРВИННА РЕЄСТРАЦIЯ ТЗ ПРИДБАНОГО В ТОРГІВЕЛЬНІЙ ОРГАНІЗАЦІЇ, УСТАНОВИ',
#        '70 - РЕЄСТРАЦIЯ ТЗ ПРИВЕЗЕНОГО З-ЗА КОРДОНУ',
#        '401 - ПЕРЕРЕЄСТРАЦІЯ ТЗ ПРИ ПЕРЕОБЛАДНАННІ ІЗ ЗАМІНОЮ КУЗОВА',
#        '50 - РЕЄСТРАЦIЯ ТЗ ЗА ДОГОВОРОМ КУПIВЛI-ПРОДАЖУ',
#        '11 - ПЕРВИННА РЕЄСТРАЦIЯ ТЗ ДЛЯ ІНШИХ ОРГ. ДЕРЖ.ВЛАСНОСТІ',
#        '69 - РЕЄСТРАЦІЯ ТЗ ПО АКТУ ПРИЙОМУ-ПЕРЕДАЧІ',
#        '350 - ПЕРЕРЕЄСТРАЦIЯ У ЗВ`ЯЗКУ ЗI ЗМIНОЮ НАЗВИ ОРГАНIЗАЦIЇ',
#        '530 - ЗНЯТТЯ З ОБЛIКУ ДЛЯ РЕАЛIЗАЦIЇ',
#        '80 - РЕЄСТРАЦIЯ ТЗ ПРИДБАНОГО НА АУКЦІОНІ ТОВАР. БIРЖI',
#        '410 - ПЕРЕРЕЄСТРАЦІЯ ПРИ ЗАМІНІ НОМЕРНОГО ЗНАКУ',
#        "221 - РЕЄСТРАЦІЮ ТЗ,ВВЕЗЕНОГО ПІД ЗОБОВ'ЯЗАННЯ ПРО ЗВОРОТНЕ ВИВЕЗЕННЯ",
#        '322 - ПЕРЕРЕЄСТРАЦIЯ ТЗ НА НОВ. ВЛАС. ПО УСПАДКУВАННЮ ЗА ЗАКОНОМ',
#        '330 - ПЕРЕРЕЄСТРАЦIЯ НА НОВОГО ВЛАСНИКА ЗА РIШЕННЯМ СУДУ',
#        '130 - РЕЄСТРАЦIЯ ТЗ У ЗВ`ЯЗКУ З ПРИЇЗДОМ НА ПМЖ ',
#        '309 - ПЕРЕРЕЄСТРАЦІЯ ТЗ НА НОВОГО ВЛАСНИКА ЗА ДОВІДКОЙ-РАХУНОК',
#        '270 - ВИДАЧА ТИМЧАС. ТАЛ. ДЛЯ МОПЕДІВ БЕЗ ОБМЕЖ СТРОКУ РЕЄС.',
#        '143 - ПОНОВЛЕННЯ РЕЄСТР. ПІСЛЯ УМОВН. ЗНЯТТЯ З ОБЛ. З НЕПР. ТО',
#        '64 - РЕЄСТРАЦІЯ КОНФІСКОВАНОГО ТЗ',
#        '402 - ПЕРЕРЕЄСТРАЦIЯ ТЗ ПРИ ПЕРЕОБЛАДНАННI IЗ ЗАМIНОЮ ДВИГУНА',
#        '340 - ПЕРЕРЕЄСТРАЦIЯ У ЗВ`ЯЗКУ ЗI ЗМIНОЮ АНКЕТНИХ ДАНИХ ВЛАСНИКА',
#        '65 - РЕЄСТРАЦIЯ ТЗ ЗА РІШЕННЯМ СУДУ',
#        '101 - РЕЄСТРАЦIЯ ТЗ ЗА ДОГОВОРОМ ЛІЗИНГУ',
#        '403 - ПЕРЕРЕЄСТРАЦІЯ ПРИ ПЕРЕОБЛАДН. ІЗ ЗАМІНОЮ КУЗОВА ТА ДВИГУНА',
#        '310 - ПЕРЕРЕЄСТРАЦІЯ НА НОВОГО ВЛАСНИКА ЗА ДОГ. КУПIВЛI-ПРОДАЖУ',
#        '321 - ПЕРЕРЕЄСТРАЦIЯ ТЗ НА НОВ. ВЛАС. ПО УСПАДКУВАННЮ ЗА ЗАПОВIТОМ',
#        '360 - ПЕРЕРЕЄСТРАЦIЯ У ЗВ`ЯЗКУ ЗI ЗМIНОЮ МIСЦЯ СТОЯНКИ',
#        "151 - РЕЄСТРАЦІЯ ТЗ У ЗВ'ЯЗКУ ЗІ ЗМІНОЮ МІСЦЯ СТОЯНКИ",
#        '140 - РЕЄСТРАЦIЯ ТЗ У ЗВ`ЯЗКУ З НЕПРОДАЖЕМ',
#        '20 - ПЕРВИННА РЕЄСТРАЦIЯ ТЗ ДЛЯ НЕДЕРЖ. ОРГАНIЗАЦIЇ',
#        '62 - РЕЄСТРАЦIЯ ТЗ ПО УСПАДКУВАННЮ ЗА ЗАКОНОМ',
#        '350 -  ПЕРЕРЕЄСТРАЦIЯ У ЗВ`ЯЗКУ ЗI ЗМIНОЮ НАЗВИ ОРГАНIЗАЦIЇ',
#        '540 - ЗНЯТТЯ З ОБЛIКУ У ЗВ`ЯЗКУ З ВИБРАКОВКОЮ',
#        '370 - ПЕРЕРЕЄСТРАЦIЯ У ЗВ`ЯЗКУ З ЗАМIНОЮ ДВИГУНА',
#        '14 - ВНЕСЕННЯ БЕЗНОМЕРНОГО ТЗ (ТІЛЬКИ ДЛЯ ВИДАЧІ ДОПНВ)',
#        '533 - ЗНЯТТЯ З ОБЛIКУ ЗА ДОГОВОРОМ ДАРУВАННЯ ЧИ ЗАПОВІТОМ',
#        '440 - ПЕРЕРЕЄСТРАЦIЯ ПРИ ВИДАЧI ДУБЛIКАТА СВIДОЦТВА ПРО РЕЄСТРАЦIЮ',
#        '250 -  ВИДАЧА ТИМЧАСОВОГО РЕЄСТР ТАЛОНУ ПО ДОРУЧЕННЮ',
#        '63 - РЕЄСТРАЦIЯ ТЗ У ЗВ`ЯЗКУ З ПЕРЕДАЧЕЮ ДО СТАТУТНОГО ФОНДУ',
#        '70 - РЕЄСТРАЦIЯ ТЗ ПРИВЕЗЕНОГО З-ЗА КОРДОНУ ПО ВМД',
#        '13 -  ВИПРАВЛЕННЯ VIN-КОДУ (ПІСЛЯ ВИПРАВЛЕННЯ КАРТКУ ВИДАЛИТИ)',
#        "429 - ПЕРЕРЕЄСТРАЦІЯ ТЗ У ЗВ'ЯЗКУ ІЗ ПОДОВЖЕННЯМ ТЕРМІНУ ЗВОРОТНЬОГО ВИВОЗУ",
#        '10 - ПЕРВИННА РЕЄСТРАЦIЯ ТЗ ДЛЯ ДЕРЖБЮДЖ. ОРГ.',
#        '534 - ЗНЯТТЯ З ОБЛІКУ ЗА АКТОМ ПРИЙОМА-ПЕРЕДАЧІ',
#        '312 - ПЕРЕРЕЄСТРАЦІЯ ТЗ НА НОВОГО ВЛАСНИКА, ОТРИМАНОГО ЧЕРЕЗ ВІДДІЛ СОЦ.ЗАХИСТУ',
#        '252 -  ВИДАЧА ТИМЧАС. РЕЄСТР. ТАЛОНУ НА ПРАВО КЕР ЗА ЗАЯВОЮ ВЛ',
#        '560 -  ЗНЯТТЯ З ОБЛІКУ ПРИ ПОВЕРНЕННІ ІЗ ПОЇЗДКИ ЗА КОРДОН ПО ДОРУЧ.',
#        '210 - ВИДАЧА ТИМЧАСОВОГО ТАЛОНУ ЗА ЗАЯВОЮ ВЛАСНИКА ДЛЯ РЕЄСТРАЦІЇ У ТОМУ ЧИСЛІ ПРИ УТОЧНЕННІ РЕЄСТРАЦІЙНИХ ДАНИХ ТЗ',
#        '141 - РЕЄСТРАЦIЯ ТЗ ПIСЛЯ ВIДМIНИ ЇЇ АНУЛЮВАННЯ',
#        '200 - ВИДАЧА ТИМЧАС. ТАЛОНУ ПРИ ВТРАТI СВIД ПРО РЕЄСТРАЦIЮ',
#        '300 - ПЕРЕРЕЄСТРАЦIЯ НА НОВОГО ВЛАСНИКА ЗА СВIД. НА СПIЛЬНЕ МАЙНО',
#        '41 - ВТОРИННА РЕЄСТРАЦІЯ ТЗ, ПРИДБАНОГО В ТОРГОВЕЛЬНІЙ ОРГАНІЗАЦІЇ В РОЗСТРОЧКУ',
#        '420 - ПЕРЕРЕЄСТРАЦІЯ ПРИ ВТРАТІ НОМЕРНОГО ЗНАКУ',
#        '360 -  ПЕРЕРЕЄСТРАЦIЯ У ЗВ`ЯЗКУ ЗI ЗМIНОЮ МIСЦЯ СТОЯНКИ',
#        '251 -  ВИДАЧА ТИМЧАС. РЕЄСТР. ТАЛОНУ ПО ДОРУЧ. ДЛЯ ТЗ IНШ РЕГ',
#        "500 - ЗНЯТТЯ З ОБЛІКУ У ЗВ'ЯЗКУ ЗІ СКАСУВАННЯМ РЕЄСТРАЦІЇ",
#        '110 - РЕЄСТРАЦIЯ ТЗ ОТРИМАНОГО ЧЕРЕЗ ВIДДIЛ СОЦ. ЗАХИСТУ',
#        '90 - РЕЄСТРАЦIЯ ТЗ ПРИДБАНОГО З ФОНДІВ МІН. ОБОРОНИ',
#        '320 - ПЕРЕРЕЄСТРАЦIЯ НА НОВ. ВЛАС. ЗА ДОГ. ДАРУВАННЯ',
#        '431 - ПЕРЕРЕЄСТРАЦІЯ ТЗ ПРИ ВИДАЧІ ІНДИВІДУАЛЬНОГО НОМЕРНОГО ЗНАКУ',
#        '420 - ПЕРЕРЕЄСТРАЦІЯ ПРИ ВИДАЧІ ДУБЛІКАТА НОМЕРНОГО ЗНАКУ',
#        '390 - ПЕРЕРЕЄСТРАЦIЯ У ЗВ`ЯЗКУ ЗI ЗМIНОЮ КОЛЬОРУ ТЗ',
#        '311 - ПЕРЕРЕЄСТРАЦIЯ НА НОВОГО ВЛАСНИКА ЗА ДОГОВОРОМ МIНИ',
#        '380 - ПЕРЕРЕЄСТРАЦІЯ У ЗВ`ЯЗКУ З ЗАМІНОЮ КУЗОВА (ШАСІ)',
#        '570 - ЗНЯТТЯ З ОБЛІКУ У ЗВ`ЯЗКУ ЗI ЗМIНОЮ ОРГАНУ РЕЄСТРАЦІЇ',
#        "131 - РЕЄСТРАЦІЯ ТЗ У ЗВ'ЯЗКУ З ПРИЇЗДОМ НА ПМЖ В МЕЖАХ ОБЛАСТІ",
#        '100 - ПЕРВИННА РЕЄСТРАЦIЯ ТЗ ПРИДБАНОГО В ТОРГІВЕЛЬНІЙ ОРГАНІЗАЦІЇ, ЯКИЙ ВВЕЗЕНО З-ЗА КОРДОНУ',
#        '120 - РЕЄСТРАЦIЯ ТЗ ОТРИМАНОГО ПО ВИГРАШУ',
#        '510 - ЗНЯТТЯ З ОБЛІКУ ПРИ ЗМІНІ МІСЦЯ ПРОЖИВАННЯ В МЕЖАХ УКРАЇНИ',
#        '322 -  ПЕРЕРЕЄСТРАЦIЯ ТЗ НА НОВ. ВЛАС. ПО УСПАДКУВАННЮ ЗА ЗАКОНОМ',
#        "220 - ВИДАЧА ТИМЧАСОВОГО ТАЛОНУ ПРИ ЗОБОВ'ЯЗАННІ ПРО ЗВОРОТНЕ ВИВЕЗЕННЯ",
#        '50 - ВТОРИННА РЄСТРАЦIЯ ТЗ ЗА ДОГОВОРОМ КУПIВЛI-ПРОДАЖУ',
#        '61 - РЕЄСТРАЦIЯ ТЗ ПО УСПАДКУВАННЮ ЗА ЗАПОВIТОМ',
#        '520 - ЗНЯТТЯ З ОБЛIКУ ПРИ ВИЇЗДІ ЗА КОРДОН НА ПОСТ. МІСЦЕ ПРОЖИВ.',
#        '60 - РЕЄСТРАЦIЯ ТЗ ЗА ДОГОВОРОМ ДАРУВАННЯ',
#        '255 -  АНУЛЮВАННЯ ВИДАЧI ТИМЧАС. РЕЄСТРАЦIЙНОГО ТАЛОНУ ПО ДОРУЧ',
#        '230 -  ВИДАЧА СВ. ПРО РЕЄСТР ДЛЯ ПОЇЗДКИ ЗА КОРДОН',
#        '531 - ЗНЯТТЯ З ОБЛIКУ ЗА ДОГОВОРОМ КУПIВЛI-ПРОДАЖУ',
#        '310 - ПЕРЕРЕЄСТРАЦІЯ НА НОВОГО ВЛАСНИКА ЗА ДОГ. КУП.-ПРОД.(ОФОРМ.НОТАРІАЛЬНО ТА ІНШ.)',
#        '150 - РЕЄСТРАЦIЯ ТЗ САМОСТIЙНО СКЛАДЕНОГО',
#        '319 - ПЕРЕРЕЄСТРАЦІЯ ТЗ НА НОВОГО ВЛАСНИКА ЗА АКТОМ ПРИЙОМУ-ПЕРЕДАЧІ',
#        '140 - ВТОРИННА РЕЄСТРАЦIЯ ТЗ У ЗВ`ЯЗКУ З НЕПРОДАЖЕМ',
#        '550 - ЗНЯТТЯ З ОБЛIКУ ТЗ ВВЕЗЕНОГО ПIД ЗОБОВ. ПРО ЗВОР. ВИВЕЗЕННЯ',
#        '532 - ЗНЯТТЯ З ОБЛIКУ ЗА ДОГОВОРОМ МІНИ',
#        "131 - РЕЄСТРАЦІЯ ТЗ У ЗВ'ЯЗКУ З ПРИЇЗДОМ НА ПМП В МЕЖАХ УКРАЇНИ",
#        '240 -  ПОСТАНОВКА НА ТИМЧАСОВИЙ ОБЛIК ТЗ ПРИБУЛОГО З IНШ. РЕГ',
#        '400 - ПЕРЕРЕЄСТРАЦIЯ ПРИ ПЕРЕОБЛАДНАННI БЕЗ ЗАМІНИ НОМЕРНИХ АГРЕГАТІВ',
#        '402 - ПЕРЕРЕЄСТРАЦIЯ ТЗ ПРИ ПЕРЕОБЛАДНАННI, В ТОМУ ЧИСЛІ ЗАМІНА ТИПУ, ПОТУЖНОСТІ ДВИГУНА',
#        '403 - ПЕРЕРЕЄСТРАЦІЯ ПРИ ПЕРЕОБЛАДНАННІ ІЗ ЗАМІНОЮ КУЗОВА (ШАСІ) ТА ДВИГУНА',
#        '310 - ПЕРЕРЕЄСТРАЦІЯ НА НОВОГО ВЛАСНИКА ЗА ДОГ. КУП.-ПРОД.ТА ІНШ.(ОФОРМ.НОТАРІАЛЬНО )',
#        '142 - РЕЄСТРАЦІЯ БЕЗХАЗЯЙНОГО ТЗ',
#        '500 - ЗНЯТТЯ З ОБЛІКУ У ЗВ`ЯЗКУ З АНУЛЮВАННЯМ РЕЄСТРАЦІЇ',
#        '402 - ПЕРЕРЕЄСТРАЦIЯ ТЗ ПРИ ПЕРЕОБЛI.(ЗАМІНА ТИПУ, ПОТУЖ. ДВИГ.)ЗА ПОГОДЖЕННЯМ',
#        '51 - РЕЄСТРАЦIЯ ТЗ ЗА ДОГОВОРОМ МІНИ',
#        '401 - ПЕРЕРЕЄСТРАЦІЯ ТЗ ПРИ ПЕРЕОБЛАДНАННІ ІЗ ЗАМІНОЮ КУЗОВА (ШАСІ)',
#        '341 - ПЕРЕРЕЄСТРАЦІЯ РАНІШЕ ВИКРАДЕНОГО ТЗ',
#        '309 - ПЕРЕРЕЄСТРАЦІЯ ТЗ НА НОВОГО ВЛАСНИКА ЗА ДОВІДКОЮ-РАХУНКОМ',
#        '400 - ПЕРЕРЕЄСТРАЦIЯ ПРИ ПЕРЕОБЛАДНАННI ДЛЯ РОБОТИ НА ГАЗОВОМУ ПАЛЬНОМУ',
#        '370 - ПЕРЕРЕЄСТРАЦIЯ У ЗВ`ЯЗКУ З ЗАМIНОЮ ДВИГУНА, БЕЗ ЗДІЙСНЕННЯ ПЕРЕОБЛАДНАННЯ ТЗ',
#        '260 - ВИДАЧА ТИМЧ. РЕЄСТР. ТАЛОНУ ПРИ ВИЯВЛЕННI ТЗ ВИКР ЗА КОРД',
#        '15 - ВНЕСЕННЯ БЕЗНОМЕРНОГО ТЗ (ТІЛЬКИ ДЛЯ ВИБРАКОВКИ)',
#        '561 -  ЗНЯТТЯ З ОБЛIКУ ПРИ ЗАКIНЧЕННI ТЕРМIНУ ДОРУЧЕННЯ',
#        '99 - ПЕРВИННА РЕЄСТРАЦІЯ ТЗ ПРИДБАНОГО В ТОРГІВЕЛЬНІЙ ОРГАНІЗАЦІЇ, ЯКИЙ ВИГОТОВЛЕНО В УКРАЇНІ',
#        '541 - УМОВНЕ ЗНЯТТЯ З ОБЛІКУ У ЗВ`ЯЗКУ З НЕПРОХОДЖЕННЯМ ТО',
#        "342 - ПЕРЕРЕЄСТРАЦІЯ ТЗ У ЗВЭ'ЯЗКУ З ЗАМІНОЮ СВІДОЦТВА",
#        '323 - ПЕРЕРЕЄСТРАЦІЯ НА НОВОГО ВЛАСНИКА ЗА СПАДЩИНОЮ(ЗА ЗАКОНОМ)',
#        "343 - ПЕРЕРЕЄСТРАЦІЯ У ЗВ'ЯЗКУ ІЗ ЗМІНОЮ ДАНИХ ВЛАСНИКА АБО ТЗ ОТРИМАНОГО ЧЕРЕЗ ВІДДІЛ СОЦЗАХИСТУ",
#        '212 - ВИДАЧА ТИМЧАСОВОГО ТАЛОНА ЗА ЗАЯВОЮ ВЛАСНИКА ДЛЯ ПЕРЕРЕЄСТРАЦІЇ У ТОМУ ЧИСЛІ ПРИ УТОЧНЕНІ ДАНИХ ТЗ',
#        "552 - ЗНЯТТЯ ТЗ З ОБЛІКУ,ВВЕЗЕНОГО ПІД ЗОБОВ'ЯЗАННЯ ПРО ЗВОРОТНЕ ВИВЕЗЕННЯ",
#        '554 - ЗНЯТТЯ З ОБЛІКУ ТЗ ЗА АКТОМ ПРИЙОМУ-ПЕРЕДАЧІ',
#        '256 -  АНУЛЮВАННЯ ВИДАЧI ТИМЧАС. РЕЕСТР. ТАЛОНУ ПО ЗАЯВI ВЛ',
#        '403 - ПЕРЕРЕЄСТРАЦІЯ ПРИ ПЕРЕОБЛ.(ЗАМІНА КУЗОВА (ШАСІ)) ТА ДВИГУНА ЗА ПОГОДЖ.',
#        '50 - ВТОРИННА РЕЄСТРАЦIЯ ТЗ ЗА ДОГОВОРОМ КУПIВЛI-ПРОДАЖУ',
#        '402 - ПЕРЕРЕЄСТРАЦIЯ ТЗ ПРИ ПЕРЕОБЛАДНАННI, ЗАМIНА ДВИГУНА (ЗМІНА ОБЄМУ, ВИДУ ПАЛЬНОГО)',
#        '53 - ЗНЯТТЯ ТЗ З ОБЛІКУ ЗА РІШЕННЯМ СУДУ',
#        '402 - ПЕРЕРЕЄСТРАЦIЯ ТЗ ПРИ ПЕРЕОБЛАДНАННI, В ТОМУ ЧИСЛІ ЗАМІНА ТИПУ, ПОТУЖНОСТІ ДВИГУНА ЗА ПОГОДЖЕННЯМ',
#        '501 - АНУЛЮВАННЯ ЗНЯТТЯ З ОБЛІКУ ТЗ',
#        '67 - РЕЄСТРАЦИЯ ТЗ ЗА НОВИМ ВЛАСНИКОМ ЗГIДНО РIШЕННЯ СУДУ',
#        "429 -  ПЕРЕРЕЄСТРАЦІЯ ТЗ У ЗВ'ЯЗКУ ІЗ ПОДОВЖЕННЯМ ТЕРМІНУ ЗВОРОТНЬОГО ВИВОЗУ",
#        '580 - ЗНЯТТЯ З ОБЛІКУ ТЗ ДЛЯ ПОВЕРНЕННЯ ОРГАНАМ СОЦ. ЗАХИСТУ',
#        "553 - ЗНЯТТЯ ТЗ З ОБЛІКУ,ВВЕЗЕНОГО ПІД ЗОБОВ'ЯЗАННЯ ПРО ЗВОРОТНЕ ВИВЕЗЕННЯ",
#        '331 - ПЕРЕРЕЄСТРАЦІЯ ТЗ НА НОВОГО ВЛАСНИКА ЗА АКТОМ ПРОВЕДЕНОГО АУКЦІОНУ',
#        '332 - ПЕРЕРЕЄСТРАЦІЯ ТЗ НА НОВОГО ВЛАСНИКА ЗА ПОСТАНОВОЮ ПРО ПЕРЕДАЧУ МАЙНА',
#        '550 -  ЗНЯТТЯ З ОБЛIКУ ТЗ ВВЕЗЕНОГО ПIД ЗОБОВ. ПРО ЗВОР. ВИВЕЗЕННЯ',
#        '400 -  ПЕРЕРЕЄСТРАЦIЯ ПРИ ПЕРЕОБЛАДНАННI БЕЗ ЗАМIНИ НОМЕРНИХ АГРЕГ.',
#        '534 -  ЗНЯТТЯ З ОБЛІКУ ЗА АКТОМ ПРИЙОМА-ПЕРЕДАЧІ',
#        '140 -  РЕЄСТРАЦIЯ ТЗ У ЗВ`ЯЗКУ З НЕПРОДАЖЕМ',
#        '309 -  ПЕРЕРЕЄСТРАЦІЯ ТЗ НА НОВОГО ВЛАСНИКА ЗА ДОВІДКОЙ-РАХУНОК',
#        '402 - ПЕРЕРЕЄСТРАЦIЯ ТЗ ПРИ ПЕРЕОБЛАДНАННI IЗ ЗАМIНОЮ ДВИГУНА (ЗМІНА ОБЄМУ, ВИДУ ПАЛЬНОГО)',
#        '530 -  ЗНЯТТЯ З ОБЛIКУ ДЛЯ РЕАЛIЗАЦIЇ',
#        '330 -  ПЕРЕРЕЄСТРАЦIЯ НА НОВОГО ВЛАСНИКА ЗА РIШЕННЯМ СУДУ',
#        '560 - ЗНЯТТЯ З ОБЛІКУ ПРИ ПОВЕРНЕННІ ІЗ ПОЇЗДКИ ЗА КОРДОН ПО ДОРУЧ.',
#        '40 -  ВТОРИННА РЕЄСТРАЦІЯ ТЗ, ПРИДБАНОГО В ТОРГОВЕЛЬНІЙ ОРГАНІЗАЦІЇ',
#        "542 - ЗНЯТТЯ З ОБЛІКУ У ЗВ'ЯЗКУ З УТІЛІЗАЦІЄЮ",
#        '570 - ЗНЯТТЯ З ОБЛІКУ У ЗВ`ЯЗКУ ЗI ЗМIНОЮ ДЕРЖАВНОГО ОРГАНУ РЕЄСТРАЦІЇ',
#        '210 -  ВИДАЧА ТИМЧАСОВОГО ТАЛОНУ ЗА ЗАЯВОЮ ВЛАСНИКА ДЛЯ РЕЄСТРАЦІЇ У ТОМУ ЧИСЛІ ПРИ УТОЧНЕННІ РЕЄСТРАЦІЙНИХ ДАНИХ ТЗ',
#        '430 -  ПЕРЕРЕЄСТРАЦІЯ ПРИ ЗАМІНІ СВІДОЦТВА ПРО РЕЄСТРАЦІЮ',
#        '440 -  ПЕРЕРЕЄСТРАЦIЯ ПРИ ВИДАЧI ДУБЛIКАТА СВIДОЦТВА ПРО РЕЄСТРАЦIЮ',
#        '540 -  ЗНЯТТЯ З ОБЛIКУ У ЗВ`ЯЗКУ З ВИБРАКОВКОЮ',
#        '100 -  ПЕРВИННА РЕЄСТРАЦIЯ ТЗ ПРИДБАНОГО В ТОРГІВЕЛЬНІЙ ОРГАНІЗАЦІЇ, УСТАНОВИ',
#        '340 -  ПЕРЕРЕЄСТРАЦIЯ У ЗВ`ЯЗКУ ЗI ЗМIНОЮ АНКЕТНИХ ДАНИХ ВЛАСНИКА',
#        '70 -  РЕЄСТРАЦIЯ ТЗ ПРИВЕЗЕНОГО З-ЗА КОРДОНУ ПО ВМД',
#        '300 -  ПЕРЕРЕЄСТРАЦIЯ НА НОВОГО ВЛАСНИКА ЗА СВIД. НА СПIЛЬНЕ МАЙНО',
#        '69 -  РЕЄСТРАЦІЯ ТЗ ПО АКТУ ПРИЙОМУ-ПЕРЕДАЧІ',
#        '321 -  ПЕРЕРЕЄСТРАЦIЯ ТЗ НА НОВ. ВЛАС. ПО УСПАДКУВАННЮ ЗА ЗАПОВIТОМ',
#        '252 - ВИДАЧА ТИМЧАС. РЕЄСТР. ТАЛОНУ НА ПРАВО КЕР ЗА ЗАЯВОЮ ВЛ',
#        '319 -  ПЕРЕРЕЄСТРАЦІЯ ТЗ НА НОВОГО ВЛАСНИКА ЗА АКТОМ ПРИЙОМУ-ПЕРЕДАЧІ',
#        '410 -  ПЕРЕРЕЄСТРАЦІЯ ПРИ ЗАМІНІ НОМЕРНОГО ЗНАКУ',
#        '403 -  ПЕРЕРЕЄСТРАЦІЯ ПРИ ПЕРЕОБЛАДН. ІЗ ЗАМІНОЮ КУЗОВА ТА ДВИГУНА',
#        '50 -  РЕЄСТРАЦIЯ ТЗ ЗА ДОГОВОРОМ КУПIВЛI-ПРОДАЖУ',
#        '101 -  РЕЄСТРАЦIЯ ТЗ ЗА ДОГОВОРОМ ЛІЗИНГУ',
#        '65 -  РЕЄСТРАЦIЯ ТЗ ЗА РІШЕННЯМ СУДУ',
#        '310 -  ПЕРЕРЕЄСТРАЦІЯ НА НОВОГО ВЛАСНИКА ЗА ДОГ. КУПIВЛI-ПРОДАЖУ',
#        '402 -  ПЕРЕРЕЄСТРАЦIЯ ТЗ ПРИ ПЕРЕОБЛАДНАННI IЗ ЗАМIНОЮ ДВИГУНА',
#        '535 - ЗНЯТТЯ З ОБЛІКУ ЗА ДОГОВОРОМ ФІНАНСОВОГО ЛІЗИНГУ',
#        '71 - РЕЄСТРАЦІЯ ТЗ ПРИВЕЗЕНОГО З-ЗА КОРДОНУ ПО ПОСВІДЧЕННЮ МИТНИЦІ',
#        '16 - ВНЕСЕННЯ КАРТКИ ТЗ (ПІСЛЯ ВИВЕЗЕННЯ ЗА КОРДОН ТА ПОВТОРНОГО ВВЕЗЕННЯ)',
#        '315 - ПЕРЕРЕЄСТРАЦІЯ ТЗ НА НОВ. ВЛАСН. ПО ДОГОВОРУ УКЛАДЕНОМУ В ТСЦ',
#        '48 - ВТОРИННА РЕЄСТРАЦІЯ ТЗ ПО ДОГ. КУП.-ПРОД. УКЛАД. В ТСЦ (ПІСЛЯ 530 АБО 531)',
#        '49 - ВТОРИННА РЕЄСТРАЦІЯ ТЗ ПО ДОГОВОРУ УКЛАДЕНОМУ В ТСЦ',
#        '536 - ЗНЯТТЯ З ОБЛІКУТЗ (ДОГОВІР УКЛАДЕНИЙ В ТСЦ)',
#        '172 - ПЕРВИННА РЕЄСТРАЦІЯ ЛЕГКОВИХ ТЗ, ЯКІ ВВЕЗЕНО З-ЗА КОРДОНУ',
#        '308 - ПЕРЕРЕЄСТРАЦІЯ НА НОВОГО ВЛАСНИКА ЗА ДОГ. КУПIВЛI-ПРОДАЖУ (СГ)',
#        '17 - ПЕРВИННА РЕЄСТРАЦІЯ ТЗ (МОПЕДІВ) ЗА ВИСНОВКАМИ',
#        '363 - ПЕРЕРЕЄСТРАЦIЯ ТЗ У ЗВ`ЯЗКУ З ПЕРЕДАЧЕЮ ДО СТАТУТНОГО ФОНДУ',
#        '470 - ВИДАЧА ДУБЛІКАТУ ТИМЧ.ТАЛ.ДЛЯ МОПЕДІВ ПІСЛЯ ВТРАТИ АБО ЗМІНИ АНКЕТНИХ ДАНИХ ВЛАСНИКА',
#        '417 - ПЕРЕРЕЄСТРАЦІЯ ТЗ (МОПЕДІВ) З ВИДАЧОЮ СПР',
#        '570 - ЗНЯТТЯ З ОБЛІКУ У ЗВ`ЯЗКУ ЗI ЗМIНОЮ ДЕРЖАВНОГ ОРГАНУ РЕЄСТРАЦІЇ',
#        '500 - ЗНЯТТЯ З ОБЛІКУ У ЗВ`ЯЗКУ З СКАСУВАНЯМ РЕЄСТРАЦІЇ',
#        '380 - ПЕРЕРЕЄСТРАЦІЯ У ЗВ`ЯЗКУ З ЗАМІНОЮ КУЗОВА (ШАСІ), БЕЗ ЗДІЙСНЕННЯ ПЕРЕОБЛАДНАННЯ ТЗ',
#        '536 - ЗНЯТТЯ ТЗ ПО ДОГОВОРУ УКЛАДЕНОМУ В ТСЦ',
#        '401 - ПЕРЕРЕЄСТРАЦІЯ ТЗ ПРИ ПЕРЕОБЛ.І ІЗ ЗАМ.КУЗОВА(ШАСІ) ЗА ПОГОДЖЕННЯМ',
#        '536 - УМОВНЕ ЗНЯТТЯ ТЗ З ОБЛІКУ ДЛЯ ПЕРЕРЕЄСТРАЦІЇ НА НОВОГО ВЛАСНИКА ПО ДОГОВОРУ УКЛ. В ТСЦ',
#        '310 - ПЕРЕРЕЄСТРАЦІЯ НА НОВОГО ВЛАСНИКА ЗА ДОГ. КУПIВЛI-ПРОДАЖУ (СГ)',
#        '405 - ПЕРЕРЕЄСТРАЦІЯ ТЗ, В ЗВ’ЯЗКУ ІЗ НАНЕСЕННЯ ДУБЛЮВАННЯ №ШАСІ (РАМИ)',
#        '404 - ПЕРЕРЕЄСТРАЦІЯ ТЗ, В ЗВ’ЯЗКУ ІЗ НАНЕСЕННЯ ДУБЛЮВАННЯ №КУЗОВА',
#        '324 - ПЕРЕРЕЄСТРАЦІЯ ТЗ НА НОВОГО ВЛАСНИКА (СТРАХОВИКА), ПІСЛЯ ВИПЛАТИ СТРАХУВАЛЬНИКАМ ПОВНОЇ СТРАХОВОЇ СУМИ.',
#        '301 - ПЕРЕРЕЄСТРАЦІЯ ЗА ДОГОВОРОМ ПОДІЛУ МАЙНА',
#        "343 - ПЕРЕРЕЄСТРАЦІЯ У ЗВ'ЯЗКУ ІЗ ЗМІНОЮ ДАНИХ ВЛАСНИКА АБО ТЗ (ТЗ  ОТРИМАНО ЧЕРЕЗ ВІДДІЛ СОЦЗАХИСТУ)",
#        '407 - ПЕРЕРЕЄСТРАЦІЯ У ЗВ’ЯЗКУ З ВСТАНОВЛ. СССП АВТОЖОВТОГО КОЛЬОРУ НА ТЗ РЕАГУВАННЯ СОД',
#        '16 - ВНЕСЕННЯ ВЛАСНИКА-ІНОЗЕМЦЯ (ПІСЛЯ ВИВЕЗЕННЯ ЗА КОРДОН ТА ПОВТОРНОГО ВВЕЗЕННЯ)',
#        '54 - ВТОРИННА РЕЄСТРАЦІЯ ТЗ НА НОВОГО ВЛАСНИКА ЗА ІНШИМ ДОГОВОРОМ, УГОДОЮ (КОНТРАКТОМ)',
#        '403 - ПЕРЕРЕЄСТРАЦІЯ ПРИ ПЕРЕОБЛАДНАННІ ІЗ ЗАМІНОЮ КУЗОВА (ШАСІ) ТА ДВИГУНА ЗА ПОГОДЖЕННЯМ З ВИРОБНИКОМ, ДП ДЕРЖАВТОТРАНСНДІПРОЕКТ ЧИ ГСЦ',
#        '401 - ПЕРЕРЕЄСТРАЦІЯ ТЗ ПРИ ПЕРЕОБЛАДНАННІ ІЗ ЗАМІНОЮ КУЗОВА (ШАСІ) ЗА ПОГОДЖЕННЯМ З ВИРОБНИКОМ, ДП ДЕРЖАВТОТРАНСНДІПРОЕКТ ЧИ ГСЦ МВС',
#        '401 - ПЕРЕРЕЄСТРАЦІЯ ТЗ ПРИ ПЕРЕОБЛАДНАННІ ІЗ ЗАМІНОЮ КУЗОВА(ШАСІ)',
#        '408 - ПЕРЕРЕЄСТРАЦІЯ ПРИ ПЕРЕОБЛАДНАННІ БЕЗ ЗАМІНИ НОМЕРНИХ АГРЕГАТІВ',
#        '317 - ПЕРЕРЕЄСТРАЦІЯ ТЗ НА НОВ. ВЛАСН. ПО ДОГОВОРУ ДАРУВАННЯ УКЛАДЕНОМУ В ТСЦ',
#        '501 - СКАСУВАННЯ ЗНЯТТЯ З ОБЛІКУ ТЗ',
#        '502 -  СКАСУВАННЯ ПЕРЕРЕЄСТРАЦІЇ',
#        '321 - ПЕРЕРЕЄСТРАЦIЯ ТЗ НА НОВ. ВЛАС. ПО УСПАДКУВАННЮ ЗА ЗАПОВIТОМ ЧИ УСПАДКОВАНОМУ ДОГОВОРУ',
#        '322 - ПЕРЕРЕЄСТРАЦIЯ ТЗ НА НОВ. ВЛАС. ПО УСПАДКУВАННЮ ЗА ЗАКОНОМ ЧИ ЗНЯТТЯМ З ОБЛІКУ В ОРГАНАХ СОЦЗАХИСТУ',
#        '404 - ПЕРЕРЕЄСТРАЦІЯ ТЗ, В ЗВ’ЯЗКУ ІЗ НАНЕСЕННЯ СПЕЦІАЛЬНИХ ІНДИВІДУАЛЬНИХ НОМЕРІВ АБО ДУБЛЮВАННЯ №КУЗОВА',
#        '69 - РЕЄСТРАЦІЯ НОВИХ ТЗ ПО АКТУ ПРИЙОМУ-ПЕРЕДАЧІ (ДОД. 6)',
#        '252 -  ВИДАЧА ТИМЧАС. РЕЄСТР. ТАЛОНУ НА ПРАВО КЕР ЗА ЗАЯВОЮ ВЛ.ЧИ ІНШОГО ДОКУМ.ПРАВОКОРИСТУВАННЯ ',
#        '340 - ПЕРЕРЕЄСТРАЦIЯ У ЗВ`ЯЗКУ ЗI ЗМIНОЮ АНКЕТНИХ ДАНИХ ВЛАСНИКА(БЕЗ ЗМІНИ РЕГІОНУ РЕЄСТРАЦІЇ)',
#        '80 - РЕЄСТРАЦIЯ ТЗ ПРИДБАНОГО НА АУКЦІОНІ ТОВАР. БІРЖІ',
#        '331 - ПЕРЕРЕЄСТРАЦІЯ НА НОВОГО ВЛАСНИКА ТЗ, ПРИДБАНОГО НА АУКЦІОНІ, ЕЛЕКТРОННИХ ТОРГАХ, ТОВАРНІЙ БІРЖІ',
#        '405 - ПЕРЕРЕЄСТРАЦІЯ ТЗ, В ЗВ’ЯЗКУ ІЗ НАНЕСЕННЯ СПЕЦІАЛЬНИХ ІНДИВІДУАЛЬНИХ НОМЕРІВ АБО ДУБЛЮВАННЯ №ШАСІ (РАМИ)',
#        '100 - ПЕРВИННА РЕЄСТРАЦIЯ Б/В ТЗ ПРИДБАНОГО В ТОРГІВЕЛЬНІЙ ОРГАНІЗАЦІЇ, ЯКИЙ ВВЕЗЕНО З-ЗА КОРДОНУ',
#        '141 - РЕЄСТРАЦIЯ ТЗ ПIСЛЯ ВIДМIНИ ЇЇ СКАСУВАННЯ',
#        '141 - РЕЄСТРАЦIЯ ТЗ ПIСЛЯ СКАСУВАННЯ РЕЄСТРАЦІЇ',
#        '508 -  ПЕРЕРЕЄСТРАЦІЯ ТЗ, В ЗВ’ЯЗКУ ІЗ РОЗІРВАННЯМ НОТАРІАЛЬНО ПОСВІДЧЕНОГО ДКП ЗА ЗГОДОЮ СТОРІН',
#        '502 - СКАСУВАННЯ ПЕРЕРЕЄСТРАЦІЇ',
#        '69 - РЕЄСТРАЦІЯ ТЗ ПО АКТУ ПРИЙОМУ-ПЕРЕДАЧІ (ДОД. 6)',
#        '105 - ПЕРВИННА РЕЄСТРАЦІЯ НОВОГО ТЗ ПРИДБАНОГО В ТОРГІВЕЛЬНІЙ ОРГАНІЗАЦІЇ, ЯКИЙ ВВЕЗЕНО З-ЗА КОРДОНУ',
#        '360 - ПЕРЕРЕЄСТРАЦІЯ ТЗ У ЗВ`ЯЗКУ ЗІ ЗМІНОЮ АНКЕТНИХ ДАНИХ ВЛАСНИКА (З ЗМІНОЮ РЕГІОНУ РЕЄСТРАЦІЇ)».',
#        '320 - ПЕРЕРЕЄСТРАЦIЯ НА НОВ. ВЛАС. ЗА ДОГ. ДАРУВАННЯ (ОФОРМЛЕНО НОТАРІАЛЬНО)',
#        '10 - РЕЄСТРАЦIЯ ТЗ ПО АКТУ ПРИЙМАННЯ ПЕРЕДАЧІ(ДОД.2)',
#        '60 - ВТОРИННА РЕЄСТРАЦІЯ ТЗ ЗА ДОГОВОРОМ ДАРУВАННЯ (ОФОРМЛЕНО НОТАРІАЛЬНО)',
#        '520 - ЗНЯТТЯ З ОБЛIКУ ПРИ ВИВЕЗЕНІ ЗА КОРДОН',
#        '130 - РЕЄСТРАЦIЯ ТЗ У ЗВ`ЯЗКУ З ПРИЇЗДОМ НА ПМЖ ІЗ ЗА КОРДОНУ',
#        "131 - РЕЄСТРАЦІЯ ТЗ У ЗВ'ЯЗКУ З ПРИЇЗДОМ НА ПМЖ В МЕЖАХ УКРАЇНИ",
#        '51 - ВТОРИННА РЕЄСТРАЦIЯ ТЗ ЗА ДОГОВОРОМ МІНИ (ОФОРМЛЕНО НОТАРІАЛЬНО)',
#        '329 - ПЕРЕРЕЄСТРАЦІЯ ТЗ ЗА ДОГОВОРОМ ФІНАНСОВОГО ЛІЗИНГУ',
#        '253 -  ВИДАЧА ТИМЧАСОВОГО ТАЛОНУ В УПРАВЛІННЯ, ЗГІДНО ЗАКОНУ ПРО НАЦАГЕНСТВО УПРАВЛІННЯ АКТИВАМИ',
#        '80 - РЕЄСТРАЦІЯ ТЗ ПРИДБАНОГО НА АУКЦІОНІ, ЕЛЕКТРОННИХ ТОРГАХ, ТОВАРНІЙ БІРЖІ',
#        '421 - ПЕРЕРЕЄСТРАЦІЯ ТЗ ПРИ ВТРАТІ НОМЕРНОГО ЗНАКУ ТА СВІДОЦТВА ПРО РЕЄСТРАЦІЮ',
#        '72 - РЕЄСТРАЦІЯ НОВОГО ТЗ, ПРИВЕЗЕНОГО З-ЗА КОРДОНУ ПО ВМД',
#        '520 - ЗНЯТТЯ З ОБЛIКУ ПРИ ВИВЕЗЕННІ ЗА КОРДОН',
#        '220 - ВИДАЧА ТИМЧАСОВОГО ТАЛОНА ПРИ ТИМЧАСОВОМУ ВВЕЗЕННЮ ТЗ НА МИТНУ ТЕРИТОРІЮ УКРАЇНИ',
#        'ПЕРЕРЕЄСТРАЦIЯ ПРИ ВТРАТІ СВIДОЦТВА ПРО РЕЄСТРАЦIЮ',
#        'ПЕРЕРЕЄСТРАЦІЯ ТЗ ЗА ДОГОВОРОМ ФІНАНСОВОГО ЛІЗИНГУ',
#        'ПЕРЕРЕЄСТРАЦІЯ ТЗ НА НОВ. ВЛАСН. ПО ДОГОВОРУ УКЛАДЕНОМУ В ТСЦ',
#        'ПЕРЕРЕЄСТРАЦIЯ У ЗВ`ЯЗКУ ЗI ЗМIНОЮ НАЗВИ ОРГАНIЗАЦIЇ',
#        'ПЕРВИННА РЕЄСТРАЦIЯ Б/В ТЗ ПРИДБАНОГО В ТОРГІВЕЛЬНІЙ ОРГАНІЗАЦІЇ, ЯКИЙ ВВЕЗЕНО З-ЗА КОРДОНУ',
#        'ПЕРЕРЕЄСТРАЦIЯ У ЗВ`ЯЗКУ ЗI ЗМIНОЮ АНКЕТНИХ ДАНИХ ВЛАСНИКА(БЕЗ ЗМІНИ РЕГІОНУ РЕЄСТРАЦІЇ)',
#        'ПЕРЕРЕЄСТРАЦIЯ ПРИ ПЕРЕОБЛАДНАННI ДЛЯ РОБОТИ НА ГАЗОВОМУ ПАЛЬНОМУ',
#        'ВИДАЧА ТИМЧАС. РЕЄСТР. ТАЛОНУ НА ПРАВО КЕРУВАННЯ ЗА ЗАЯВОЮ ВЛАСНИКА',
#        'ПЕРВИННА РЕЄСТРАЦІЯ НОВОГО ТЗ ПРИДБАНОГО В ТОРГІВЕЛЬНІЙ ОРГАНІЗАЦІЇ, ЯКИЙ ВВЕЗЕНО З-ЗА КОРДОНУ',
#        'РЕЄСТРАЦІЯ ТЗ ПРИВЕЗЕНОГО З-ЗА КОРДОНУ ПО ПОСВІДЧЕННЮ МИТНИЦІ',
#        'ЗНЯТТЯ З ОБЛІКУ ПРИ ПОВЕРНЕННІ ІЗ ПОЇЗДКИ ЗА КОРДОН ПО ДОРУЧ.',
#        'ПЕРВИННА РЕЄСТРАЦІЯ ТЗ (МОПЕДІВ) ЗА ВИСНОВКАМИ',
#        'ПЕРЕРЕЄСТРАЦІЯ НА НОВОГО ВЛАСНИКА ЗА ДОГ. КУПIВЛI-ПРОДАЖУ (СГ)',
#        'РЕЄСТРАЦIЯ ТЗ ПРИВЕЗЕНОГО З-ЗА КОРДОНУ ПО ВМД',
#        'ПЕРВИННА РЕЄСТРАЦІЯ ТЗ ПРИДБАНОГО В ТОРГІВЕЛЬНІЙ ОРГАНІЗАЦІЇ, ЯКИЙ ВИГОТОВЛЕНО В УКРАЇНІ',
#        'ПЕРЕРЕЄСТРАЦІЯ ПРИ ЗАМІНІ СВІДОЦТВА ПРО РЕЄСТРАЦІЮ',
#        'ПЕРЕРЕЄСТРАЦІЯ ТЗ, В ЗВ’ЯЗКУ ІЗ НАНЕСЕННЯ СПЕЦІАЛЬНИХ ІНДИВІДУАЛЬНИХ НОМЕРІВ АБО ДУБЛЮВАННЯ №ШАСІ (РАМИ)',
#        'ПЕРЕРЕЄСТРАЦІЯ ПРИ ПЕРЕОБЛАДНАННІ БЕЗ ЗАМІНИ НОМЕРНИХ АГРЕГАТІВ',
#        'ПЕРЕРЕЄСТРАЦIЯ У ЗВ`ЯЗКУ ЗI ЗМIНОЮ КОЛЬОРУ ТЗ',
#        'ПЕРЕРЕЄСТРАЦІЯ ПРИ ПЕРЕОБЛ.(ЗАМІНА КУЗОВА (ШАСІ)) ТА ДВИГУНА ЗА ПОГОДЖ.',
#        'ВИДАЧА ТИМЧАСОВОГО РЕЄСТР ТАЛОНУ ПО ДОРУЧЕННЮ ЧИ ІНШОГО ДОКУМ.ПРАВОКОРИСТУВАННЯ ',
#        'ПЕРЕРЕЄСТРАЦІЯ ПРИ ЗАМІНІ НОМЕРНОГО ЗНАКУ',
#        'ЗНЯТТЯ З ОБЛIКУ У ЗВ`ЯЗКУ З ВИБРАКОВКОЮ',
#        'ПЕРЕРЕЄСТРАЦIЯ ТЗ ПРИ ПЕРЕОБЛI.(ЗАМІНА ТИПУ, ПОТУЖ. ДВИГ.)ЗА ПОГОДЖЕННЯМ',
#        'ПЕРЕРЕЄСТРАЦІЯ ТЗ НА НОВОГО ВЛАСНИКА ЗА АКТОМ ПРИЙОМУ-ПЕРЕДАЧІ',
#        'РЕЄСТРАЦІЯ НОВИХ ТЗ ПО АКТУ ПРИЙОМУ-ПЕРЕДАЧІ (ДОД. 6)',
#        'ПЕРЕРЕЄСТРАЦIЯ ТЗ НА НОВ. ВЛАС. ПО УСПАДКУВАННЮ ЗА ЗАКОНОМ ЧИ ЗНЯТТЯМ З ОБЛІКУ В ОРГАНАХ СОЦЗАХИСТУ',
#        'ВИДАЧА СВ. ПРО РЕЄСТР ДЛЯ ПОЇЗДКИ ЗА КОРДОН',
#        "ЗНЯТТЯ З ОБЛІКУ У ЗВ'ЯЗКУ ЗІ СКАСУВАННЯМ РЕЄСТРАЦІЇ",
#        'РЕЄСТРАЦIЯ ТЗ ЗА РІШЕННЯМ СУДУ',
#        'ЗНЯТТЯ З ОБЛIКУ ПРИ ВИВЕЗЕННІ ЗА КОРДОН',
#        'ПЕРЕРЕЄСТРАЦІЯ ТЗ ПРИ ВИДАЧІ ІНДИВІДУАЛЬНОГО НОМЕРНОГО ЗНАКУ',
#        'ПЕРЕРЕЄСТРАЦІЯ ТЗ У ЗВ`ЯЗКУ ЗІ ЗМІНОЮ АНКЕТНИХ ДАНИХ ВЛАСНИКА (З ЗМІНОЮ РЕГІОНУ РЕЄСТРАЦІЇ)».',
#        'АНУЛЮВАННЯ ВИДАЧI ТИМЧАС. РЕЕСТР. ТАЛОНУ ПО ЗАЯВI ВЛ',
#        'АНУЛЮВАННЯ ВИДАЧI ТИМЧАС. РЕЄСТРАЦIЙНОГО ТАЛОНУ ПО ДОРУЧ',
#        'РЕЄСТРАЦІЯ НОВОГО ТЗ, ПРИВЕЗЕНОГО З-ЗА КОРДОНУ ПО ВМД',
#        'ПЕРЕРЕЄСТРАЦІЯ ТЗ, В ЗВ’ЯЗКУ ІЗ НАНЕСЕННЯ СПЕЦІАЛЬНИХ ІНДИВІДУАЛЬНИХ НОМЕРІВ АБО ДУБЛЮВАННЯ №КУЗОВА',
#        'ПЕРЕРЕЄСТРАЦIЯ НА НОВОГО ВЛАСНИКА ЗА РIШЕННЯМ СУДУ',
#        'ПЕРЕРЕЄСТРАЦІЯ ПРИ ВТРАТІ НОМЕРНОГО ЗНАКУ',
#        'ПЕРЕРЕЄСТРАЦІЯ ТЗ ПРИ ПЕРЕОБЛ.І ІЗ ЗАМ.КУЗОВА(ШАСІ) ЗА ПОГОДЖЕННЯМ',
#        'ЗНЯТТЯ З ОБЛІКУ У ЗВ`ЯЗКУ ЗI ЗМIНОЮ ДЕРЖАВНОГО ОРГАНУ РЕЄСТРАЦІЇ',
#        'РЕЄСТРАЦІЯ ТЗ ПРИДБАНОГО НА АУКЦІОНІ, ЕЛЕКТРОННИХ ТОРГАХ, ТОВАРНІЙ БІРЖІ',
#        'РЕЄСТРАЦIЯ ТЗ ПIСЛЯ СКАСУВАННЯ РЕЄСТРАЦІЇ',
#        'ПЕРВИННА РЕЄСТРАЦІЯ ЛЕГКОВИХ ТЗ, ЯКІ ВВЕЗЕНО З-ЗА КОРДОНУ',
#        'ПЕРЕРЕЄСТРАЦІЯ ТЗ НА НОВ. ВЛАСН. ПО ДОГОВОРУ ДАРУВАННЯ УКЛАДЕНОМУ В ТСЦ',
#        'ПЕРЕРЕЄСТРАЦІЯ НА НОВОГО ВЛАСНИКА ЗА ДОГ. КУП.-ПРОД.ТА ІНШ.(ОФОРМ.НОТАРІАЛЬНО )',
#        'РЕЄСТРАЦІЯ КОНФІСКОВАНОГО ТЗ',
#        "ПЕРЕРЕЄСТРАЦІЯ У ЗВ'ЯЗКУ ІЗ ЗМІНОЮ ДАНИХ ВЛАСНИКА АБО ТЗ (ТЗ  ОТРИМАНО ЧЕРЕЗ ВІДДІЛ СОЦЗАХИСТУ)",
#        'ПЕРЕРЕЄСТРАЦIЯ ТЗ НА НОВ. ВЛАС. ПО УСПАДКУВАННЮ ЗА ЗАПОВIТОМ ЧИ УСПАДКОВАНОМУ ДОГОВОРУ',
#        'ПЕРЕРЕЄСТРАЦIЯ НА НОВ. ВЛАС. ЗА ДОГ. ДАРУВАННЯ (ОФОРМЛЕНО НОТАРІАЛЬНО)',
#        'РЕЄСТРАЦIЯ ТЗ ОТРИМАНОГО ЧЕРЕЗ ВIДДIЛ СОЦ. ЗАХИСТУ',
#        'СКАСУВАННЯ ПЕРЕРЕЄСТРАЦІЇ',
#        'ПЕРЕРЕЄСТРАЦІЯ НА НОВОГО ВЛАСНИКА ТЗ, ПРИДБАНОГО НА АУКЦІОНІ, ЕЛЕКТРОННИХ ТОРГАХ, ТОВАРНІЙ БІРЖІ',
#        'ВТОРИННА РЕЄСТРАЦIЯ ТЗ У ЗВ`ЯЗКУ З НЕПРОДАЖЕМ',
#        'ПЕРЕРЕЄСТРАЦIЯ НА НОВОГО ВЛАСНИКА ЗА СВIД. НА СПIЛЬНЕ МАЙНО',
#        'НАЛЕЖНИЙ КОРИСТУВАЧ. РЕЄСТРАЦІЯ',
#        'ПЕРЕРЕЄСТРАЦІЯ ЗА ДОГОВОРОМ ПОДІЛУ МАЙНА',
#        'ВТОРИННА РЕЄСТРАЦІЯ ТЗ ПО ДОГОВОРУ УКЛАДЕНОМУ В ТСЦ',
#        'ПЕРЕРЕЄСТРАЦІЯ ТЗ НА НОВОГО ВЛАСНИКА ЗА ПОСТАНОВОЮ ПРО ПЕРЕДАЧУ МАЙНА',
#        'ЗНЯТТЯ З ОБЛIКУ ТЗ ВВЕЗЕНОГО ПIД ЗОБОВ. ПРО ЗВОР. ВИВЕЗЕННЯ',
#        "ПЕРЕРЕЄСТРАЦІЯ ТЗ У ЗВ'ЯЗКУ ІЗ ПОДОВЖЕННЯМ ТЕРМІНУ ЗВОРОТНЬОГО ВИВОЗУ",
#        "РЕЄСТРАЦІЮ ТЗ,ВВЕЗЕНОГО ПІД ЗОБОВ'ЯЗАННЯ ПРО ЗВОРОТНЕ ВИВЕЗЕННЯ",
#        'ВИДАЧА ТИМЧАСОВОГО ТАЛОНА ПРИ ТИМЧАСОВОМУ ВВЕЗЕННЮ ТЗ НА МИТНУ ТЕРИТОРІЮ УКРАЇНИ',
#        'ПЕРЕРЕЄСТРАЦІЯ РАНІШЕ ВИКРАДЕНОГО ТЗ',
#        'ПЕРЕРЕЄСТРАЦІЯ ТЗ НА НОВОГО ВЛАСНИКА, ОТРИМАНОГО ЧЕРЕЗ ВІДДІЛ СОЦ.ЗАХИСТУ',
#        'ПЕРЕРЕЄСТРАЦIЯ ТЗ У ЗВ`ЯЗКУ З ПЕРЕДАЧЕЮ ДО СТАТУТНОГО ФОНДУ',
#        'ВТОРИННА РЕЄСТРАЦIЯ ТЗ ПО АКТУ ПРИЙМАННЯ ПЕРЕДАЧІ(ДОД.2)',
#        'РЕЄСТРАЦIЯ ТЗ У ЗВ`ЯЗКУ З ПРИЇЗДОМ НА ПМЖ ІЗ ЗА КОРДОНУ',
#        'ПЕРЕРЕЄСТРАЦІЯ ТЗ (МОПЕДІВ) З ВИДАЧОЮ СПР',
#        'ПЕРЕРЕЄСТРАЦІЯ У ЗВ’ЯЗКУ З ВСТАНОВЛ. СССП АВТОЖОВТОГО КОЛЬОРУ НА ТЗ РЕАГУВАННЯ СОД',
#        'РЕЄСТРАЦIЯ ТЗ ПРИДБАНОГО З ФОНДІВ МІН. ОБОРОНИ',
#        'ПЕРВИННА РЕЄСТРАЦIЯ ТЗ ПРИДБАНОГО В ТОРГІВЕЛЬНІЙ ОРГАНІЗАЦІЇ, УСТАНОВИ',
#        'ПЕРЕРЕЄСТРАЦІЯ ПРИ ПЕРЕОБЛАДНАННІ ІЗ ЗАМІНОЮ КУЗОВА (ШАСІ) ТА ДВИГУНА',
#        'ПЕРВИННА РЕЄСТРАЦІЯ ТЗ ДЛЯ ІНДИВ. ВЛАСНИКА',
#        'ПЕРЕРЕЄСТРАЦІЯ ТЗ НА НОВОГО ВЛАСНИКА (СТРАХОВИКА), ПІСЛЯ ВИПЛАТИ СТРАХУВАЛЬНИКАМ ПОВНОЇ СТРАХОВОЇ СУМИ.',
#        'ПЕРЕРЕЄСТРАЦІЯ У ЗВ`ЯЗКУ З ЗАМІНОЮ КУЗОВА (ШАСІ), БЕЗ ЗДІЙСНЕННЯ ПЕРЕОБЛАДНАННЯ ТЗ',
#        'ПЕРЕРЕЄСТРАЦІЯ ТЗ В ЗВЯЗКУ ІЗ ВИВЕДЕННЯМ ІЗ СТАТУТНОГО ФОНДУ',
#        'ПЕРЕРЕЄСТРАЦІЯ НА НОВОГО ВЛАСНИКА ЗА ДОГОВОРОМ МІНИ',
#        'СКАСУВАННЯ ЗНЯТТЯ З ОБЛІКУ ТЗ',
#        'РЕЄСТРАЦIЯ ТЗ ЗА ДОГОВОРОМ ЛІЗИНГУ',
#        'ВТОРИННА РЕЄСТРАЦIЯ ТЗ ЗА ДОГОВОРОМ КУПIВЛI-ПРОДАЖУ',
#        'РЕЄСТРАЦIЯ ТЗ ПРИДБАНОГО НА АУКЦІОНІ ТОВАР. БIРЖI',
#        'ПЕРЕРЕЄСТРАЦІЯ НА НОВОГО ВЛАСНИКА ЗА ДОГ. КУПIВЛI-ПРОДАЖУ',
#        'ВИДАЧА ТИМЧ. РЕЄСТР. ТАЛОНУ ПРИ ВИЯВЛЕННI ТЗ ВИКР ЗА КОРД',
#        'ВТОРИННА РЕЄСТРАЦІЯ ТЗ, ПРИДБАНОГО В ТОРГОВЕЛЬНІЙ ОРГАНІЗАЦІЇ',
#        'ПЕРЕРЕЄСТРАЦІЯ ТЗ НА НОВОГО ВЛАСНИКА ЗА ДОВІДКОЮ-РАХУНКОМ',
#        'ПЕРЕРЕЄСТРАЦIЯ ПРИ ПЕРЕОБЛАДНАННI БЕЗ ЗАМІНИ НОМЕРНИХ АГРЕГАТІВ',
#        'ЗНЯТТЯ З ОБЛІКУ ТЗ ЗА РІШЕННЯМ СУДУ',
#        'ПЕРЕРЕЄСТРАЦІЯ ТЗ ПРИ ВТРАТІ НОМЕРНОГО ЗНАКУ ТА СВІДОЦТВА ПРО РЕЄСТРАЦІЮ',
#        'ПЕРВИННА РЕЄСТРАЦIЯ ТЗ ДЛЯ НЕДЕРЖ. ОРГАНIЗАЦIЇ',
#        'ПЕРЕРЕЄСТРАЦIЯ ТЗ НА НОВ. ВЛАС. ПО УСПАДКУВАННЮ ЗА ЗАКОНОМ',
#        'ВНЕСЕННЯ БЕЗНОМЕРНОГО ТЗ (ТІЛЬКИ ДЛЯ ВИБРАКОВКИ)',
#        'ВИДАЧА ТИМЧАСОВОГО ТАЛОНУ НА ПІДСТАВІ ЗАЯВИ УПРАВИТЕЛЯ ТА ДОГОВОРУ УПРАВЛІННЯ, УКЛАДЕНОГО З АРМА НАЦАГЕНСТВОМ УКРАЇНИ З ПИТАНЬ ВИЯВЛЕННЯ, РОЗШУКУ ТА УПРАВЛІННЯ АКТИВАМИ, ОДЕРЖАНИМИ ВІД КОРУПЦІЙНИХ ТА ІНШИХ ЗЛОЧИНІВ',
#        'РЕЄСТРАЦIЯ ТЗ ПРИВЕЗЕНОГО З-ЗА КОРДОНУ',
#        'РЕЄСТРАЦIЯ ТЗ У ЗВ`ЯЗКУ З ПЕРЕДАЧЕЮ ДО СТАТУТНОГО ФОНДУ',
#        'НАЛЕЖНИЙ КОРИСТУВАЧ. ВИКЛЮЧЕННЯ ВІДОМОСТЕЙ',
#        'ПЕРЕРЕЄСТРАЦIЯ У ЗВ`ЯЗКУ ЗI ЗМIНОЮ АНКЕТНИХ ДАНИХ ВЛАСНИКА',
#        'ВНЕСЕННЯ БЕЗНОМЕРНОГО ТЗ (ТІЛЬКИ ДЛЯ ВИДАЧІ ДОПНВ ТА ДУБЛЮВАННЯ КУЗОВА, ШАСІ)',
#        'ПЕРЕРЕЄСТРАЦIЯ НА НОВ. ВЛАС. ЗА ДОГ. ДАРУВАННЯ',
#        'ЗНЯТТЯ З ОБЛIКУ ДЛЯ РЕАЛIЗАЦIЇ',
#        "ПЕРЕРЕЄСТРАЦІЯ ПРИ ЗАМІНІ СВІДОЦТВА ПРО РЕЄСТРАЦІЮ У ЗВ'ЯЗКУ З КОРИГУВАННЯМ ОБЛІКОВИХ ДАНИХ ТЗ",
#        'РЕЄСТРАЦIЯ Б/В ТЗ ПРИВЕЗЕНОГО З-ЗА КОРДОНУ ПО ВМД',
#        'НАЛЕЖНИЙ КОРИСТУВАЧ.РЕЄСТРАЦІЯ (ТІЛЬКИ ДЛЯ КЕРІВНИКІВ ЮО)',
#        'ПЕРЕРЕЄСТРАЦІЯ ТЗ ПРИ ВИДАЧІ НОМЕРНОГО ЗНАКУ ВІДПОВІДНОЇ КОМБІНАЦІЇ ЦИФР',
#        'ВНЕСЕННЯ КАРТКИ ВІДОМЧОЇ РЕЄСТРАЦІЇ ТЗ (ТІЛЬКИ ДЛЯ НАДАННЯ ДОЗВОЛУ НА СПЕЦСИГНАЛ ТА УЧБОВИХ ТЗ)',
#        'РЕЄСТРАЦІЯ ТЗ ПРИДБАНОГО В ІНШОМУ ОРГАНІ ДЕРЖАВНОЇ РЕЄСТРАЦІЇ',
#        'ВИДАЧА ТИМЧАСОВОГО ТАЛОНУ НА ПІДСТАВІ ЗАЯВИ УПРАВИТЕЛЯ ТА ДОГОВОРУ УПРАВЛІННЯ, УКЛАДЕНОГО З АРМА ',
#        'РЕЄСТРАЦIЯ ТЗ САМОСТIЙНО СКЛАДЕНОГО',
#        'ВИДАЧА ТИМЧАСОВОГО ТАЛОНУ ЗА ЗАЯВОЮ ВЛАСНИКА ДЛЯ РЕЄСТРАЦІЇ У ТОМУ ЧИСЛІ ПРИ УТОЧНЕННІ РЕЄСТРАЦІЙНИХ ДАНИХ ТЗ',
#        'ЗНЯТТЯ З ОБЛІКУ КАРТКИ ВІДОМЧОЇ РЕЄСТРАЦІЇ',
#        'ПЕРЕРЕЄСТРАЦІЯ ТЗ ЗА ДОГОВОРОМ ФІНАНСОВОГО ЛІЗИНГУ ТА ДКП ПРЕДМЕТА ЛІЗІНГУ',
#        'РЕЄСТРАЦІЯ ТЗ, ПРИДБАНОГО В ТОРГОВЕЛЬНІЙ ОРГАНІЗАЦІЇ В РОЗСТРОЧКУ',
#        'РЕЄСТРАЦIЯ ТЗ ОТРИМАНОГО ПО ВИГРАШУ'], dtype=object)

# %%
# завантажуємо словник із інформацією про реєстраційні дії
oper_name_dict = pd.read_csv("oper_name.csv", sep = ";",encoding = "cp1251" )
oper_name_dict.head()
# Out:
#    oper_code                                      oper_name_new
# 0         10          ПЕРВИННА РЕЄСТРАЦIЯ ТЗ ДЛЯ ДЕРЖБЮДЖ. ОРГ.
# 1         11  ПЕРВИННА РЕЄСТРАЦIЯ ТЗ ДЛЯ ІНШИХ ОРГ. ДЕРЖ.ВЛА...
# 2         13                                    ВИПРАВЛЕННЯ VIN
# 3         14  ВНЕСЕННЯ БЕЗНОМЕРНОГО ТЗ (ТІЛЬКИ ДЛЯ ВИДАЧІ ДО...
# 4         15   ВНЕСЕННЯ БЕЗНОМЕРНОГО ТЗ (ТІЛЬКИ ДЛЯ ВИБРАКОВКИ)

# %%
# додаємо очищені дані про реєстраційні дії до основного датасету
oper_name_dict["oper_code"] = oper_name_dict["oper_code"].astype(str)
data["oper_code"] = data["oper_code"].astype(str)
data = pd.merge(data,oper_name_dict, on='oper_code',how='left')
data
# Out:
#           Unnamed: 0 person  reg_addr_koatuu oper_code  \
# 0                  0      P     5.101370e+08        40
# 1                  1      P     5.110137e+09       230
# 2                  2      P     2.310137e+09        40
# 3                  3      P     6.110100e+09       400
# 4                  4      P     6.110100e+09       400
# ...              ...    ...              ...       ...
# 13366354      443461      P              NaN        71
# 13366355      443462      P     5.104000e+08       308
# 13366356      443463      P     5.101000e+08        71
# 13366357      443464      P              NaN       308
# 13366358      443465      P     7.410137e+09       308
#
#                                                   oper_name       d_reg  \
# 0         40 - ВТОРИННА РЕЄСТРАЦІЯ ТЗ, ПРИДБАНОГО В ТОРГ...  2013-01-16
# 1         230 -  ВИДАЧА СВ. ПРО РЕЄСТР ДЛЯ ПОЇЗДКИ ЗА КО...  2013-08-29
# 2         40 - ВТОРИННА РЕЄСТРАЦІЯ ТЗ, ПРИДБАНОГО В ТОРГ...  2013-02-02
# 3         400 - ПЕРЕРЕЄСТРАЦIЯ ПРИ ПЕРЕОБЛАДНАННI БЕЗ ЗА...  2013-01-26
# 4         400 - ПЕРЕРЕЄСТРАЦIЯ ПРИ ПЕРЕОБЛАДНАННI БЕЗ ЗА...  2013-01-05
# ...                                                     ...         ...
# 13366354  РЕЄСТРАЦІЯ ТЗ ПРИВЕЗЕНОГО З-ЗА КОРДОНУ ПО ПОСВ...  05.03.2021
# 13366355  ПЕРЕРЕЄСТРАЦІЯ НА НОВОГО ВЛАСНИКА ЗА ДОГ. КУПI...  16.03.2021
# 13366356  РЕЄСТРАЦІЯ ТЗ ПРИВЕЗЕНОГО З-ЗА КОРДОНУ ПО ПОСВ...  05.03.2021
# 13366357  ПЕРЕРЕЄСТРАЦІЯ НА НОВОГО ВЛАСНИКА ЗА ДОГ. КУПI...  30.03.2021
# 13366358  ПЕРЕРЕЄСТРАЦІЯ НА НОВОГО ВЛАСНИКА ЗА ДОГ. КУПI...  25.03.2021
#
#           dep_code                                                dep  \
# 0          1305301  ВІННИЦЬКИЙ  ВРЕР УДАІ УМВС УКРАЇНИ У ВІННИЦЬКІ...
# 1             5146                                         Центр 5146
# 2             1242                                         Центр 1242
# 3             6141                                         Центр 6141
# 4             6141                                         Центр 6141
# ...            ...                                                ...
# 13366354     12373                                           ТСЦ 6843
# 13366355     12231                                           ТСЦ 0543
# 13366356     12229                                           ТСЦ 0541
# 13366357     12250                                           ТСЦ 1443
# 13366358     13960                                           ТСЦ 8048
#
#                                     brand             model  ...      kind  \
# 0                      SSANG YONG  REXTON            REXTON  ...  ЛЕГКОВИЙ
# 1                          TOYOTA  PREVIA            PREVIA  ...  ЛЕГКОВИЙ
# 2                          SKODA  OCTAVIA           OCTAVIA  ...  ЛЕГКОВИЙ
# 3                          CITROEN  JUMPY             JUMPY  ...  ЛЕГКОВИЙ
# 4         MERCEDES-BENZ  SPRINTER 313 CDI  SPRINTER 313 CDI  ...  ЛЕГКОВИЙ
# ...                                   ...               ...  ...       ...
# 13366354                            SKODA     OCTAVIA COMBI  ...  ЛЕГКОВИЙ
# 13366355                          HYUNDAI          SANTA FE  ...  ЛЕГКОВИЙ
# 13366356                          HYUNDAI          SANTA FE  ...  ЛЕГКОВИЙ
# 13366357                             FORD             C-MAX  ...  ЛЕГКОВИЙ
# 13366358                       VOLKSWAGEN            TOURAN  ...  ЛЕГКОВИЙ
#
#                     body    purpose                fuel capacity own_weight  \
# 0            УНІВЕРСАЛ-B  ЗАГАЛЬНИЙ     ДИЗЕЛЬНЕ ПАЛИВО   2696.0     2069.0
# 1            УНІВЕРСАЛ-B  ЗАГАЛЬНИЙ              БЕНЗИН   2362.0     1720.0
# 2              ХЕТЧБЕК-В  ЗАГАЛЬНИЙ              БЕНЗИН   1595.0     1245.0
# 3         ПАСАЖИРСЬКИЙ-B  ЗАГАЛЬНИЙ     ДИЗЕЛЬНЕ ПАЛИВО   1560.0     1736.0
# 4         ПАСАЖИРСЬКИЙ-B  ЗАГАЛЬНИЙ     ДИЗЕЛЬНЕ ПАЛИВО   2148.0     1995.0
# ...                  ...        ...                 ...      ...        ...
# 13366354       УНІВЕРСАЛ  ЗАГАЛЬНИЙ              БЕНЗИН   1595.0       1295
# 13366355       УНІВЕРСАЛ  ЗАГАЛЬНИЙ     ДИЗЕЛЬНЕ ПАЛИВО   2188.0       2030
# 13366356       УНІВЕРСАЛ  ЗАГАЛЬНИЙ     ДИЗЕЛЬНЕ ПАЛИВО   2188.0       2030
# 13366357       УНІВЕРСАЛ  ЗАГАЛЬНИЙ  ЕЛЕКТРО АБО БЕНЗИН   2000.0       1674
# 13366358       УНІВЕРСАЛ  ЗАГАЛЬНИЙ              БЕНЗИН   1595.0       1502
#
#           total_weight n_reg_new            region  \
# 0               2550.0  АВ1923ВТ         вінницька
# 1               2450.0  ВН8542СО           одеська
# 2               1720.0  АР6199СІ  дніпропетровська
# 3               2661.0  ВО5930ВА     тернопільська
# 4               3500.0  ВО5562ВА     тернопільська
# ...                ...       ...               ...
# 13366354          1805  ВХ8612ЕО       хмельницька
# 13366355          2570  АВ5529НО         вінницька
# 13366356          2570  АВ0875НТ         вінницька
# 13366357          2250  АН4178ОН          донецька
# 13366358          2090  СВ0975СХ              київ
#
#                                               oper_name_new
# 0         ВТОРИННА РЕЄСТРАЦІЯ ТЗ, ПРИДБАНОГО В ТОРГОВЕЛЬ...
# 1               ВИДАЧА СВ. ПРО РЕЄСТР ДЛЯ ПОЇЗДКИ ЗА КОРДОН
# 2         ВТОРИННА РЕЄСТРАЦІЯ ТЗ, ПРИДБАНОГО В ТОРГОВЕЛЬ...
# 3                                                       NaN
# 4                                                       NaN
# ...                                                     ...
# 13366354                        РЕЄСТРАЦІЯ ТЗ ПРИВЕЗЕНОГО З
# 13366355  ПЕРЕРЕЄСТРАЦІЯ НА НОВОГО ВЛАСНИКА ЗА ДОГ. КУПIВЛI
# 13366356                        РЕЄСТРАЦІЯ ТЗ ПРИВЕЗЕНОГО З
# 13366357  ПЕРЕРЕЄСТРАЦІЯ НА НОВОГО ВЛАСНИКА ЗА ДОГ. КУПIВЛI
# 13366358  ПЕРЕРЕЄСТРАЦІЯ НА НОВОГО ВЛАСНИКА ЗА ДОГ. КУПIВЛI
#
# [13366359 rows x 22 columns]

# %% [markdown]
# # Аналіз

# %%
Завантажуємо дані пілся OpenRefine
та проводимо left join many-to-one

# %%
brand_splited = pd.read_excel("brand_splited.xlsx")
brand_splited = brand_splited[["brand", "brand_new"]]
#brand_splited = brand_splited.set_index("brand_name 1")
brand_splited
# Out:
#                     brand   brand_new
# 0                       0           0
# 1      SSANG YONG  REXTON  SSANG YONG
# 2          TOYOTA  PREVIA      TOYOTA
# 3          SKODA  OCTAVIA       SKODA
# 4          CITROEN  JUMPY     CITROEN
# ...                   ...         ...
# 35231                 FSC         FSC
# 35232            BULTMANN    BULTMANN
# 35233                HAKO        HAKO
# 35234                 CTR         CTR
# 35235                  НР          НР
#
# [35236 rows x 2 columns]

# %%
data = pd.merge(data,brand_splited, on='brand',how='left')
data.head()
# Out:
#    Unnamed: 0 person  reg_addr_koatuu oper_code  \
# 0           0      P     5.101370e+08        40
# 1           1      P     5.110137e+09       230
# 2           2      P     2.310137e+09        40
# 3           3      P     6.110100e+09       400
# 4           4      P     6.110100e+09       400
#
#                                            oper_name       d_reg  dep_code  \
# 0  40 - ВТОРИННА РЕЄСТРАЦІЯ ТЗ, ПРИДБАНОГО В ТОРГ...  2013-01-16   1305301
# 1  230 -  ВИДАЧА СВ. ПРО РЕЄСТР ДЛЯ ПОЇЗДКИ ЗА КО...  2013-08-29      5146
# 2  40 - ВТОРИННА РЕЄСТРАЦІЯ ТЗ, ПРИДБАНОГО В ТОРГ...  2013-02-02      1242
# 3  400 - ПЕРЕРЕЄСТРАЦIЯ ПРИ ПЕРЕОБЛАДНАННI БЕЗ ЗА...  2013-01-26      6141
# 4  400 - ПЕРЕРЕЄСТРАЦIЯ ПРИ ПЕРЕОБЛАДНАННI БЕЗ ЗА...  2013-01-05      6141
#
#                                                  dep  \
# 0  ВІННИЦЬКИЙ  ВРЕР УДАІ УМВС УКРАЇНИ У ВІННИЦЬКІ...
# 1                                         Центр 5146
# 2                                         Центр 1242
# 3                                         Центр 6141
# 4                                         Центр 6141
#
#                              brand             model  ...            body  \
# 0               SSANG YONG  REXTON            REXTON  ...     УНІВЕРСАЛ-B
# 1                   TOYOTA  PREVIA            PREVIA  ...     УНІВЕРСАЛ-B
# 2                   SKODA  OCTAVIA           OCTAVIA  ...       ХЕТЧБЕК-В
# 3                   CITROEN  JUMPY             JUMPY  ...  ПАСАЖИРСЬКИЙ-B
# 4  MERCEDES-BENZ  SPRINTER 313 CDI  SPRINTER 313 CDI  ...  ПАСАЖИРСЬКИЙ-B
#
#      purpose             fuel capacity own_weight total_weight  n_reg_new  \
# 0  ЗАГАЛЬНИЙ  ДИЗЕЛЬНЕ ПАЛИВО   2696.0     2069.0       2550.0   АВ1923ВТ
# 1  ЗАГАЛЬНИЙ           БЕНЗИН   2362.0     1720.0       2450.0   ВН8542СО
# 2  ЗАГАЛЬНИЙ           БЕНЗИН   1595.0     1245.0       1720.0   АР6199СІ
# 3  ЗАГАЛЬНИЙ  ДИЗЕЛЬНЕ ПАЛИВО   1560.0     1736.0       2661.0   ВО5930ВА
# 4  ЗАГАЛЬНИЙ  ДИЗЕЛЬНЕ ПАЛИВО   2148.0     1995.0       3500.0   ВО5562ВА
#
#              region                                      oper_name_new  \
# 0         вінницька  ВТОРИННА РЕЄСТРАЦІЯ ТЗ, ПРИДБАНОГО В ТОРГОВЕЛЬ...
# 1           одеська        ВИДАЧА СВ. ПРО РЕЄСТР ДЛЯ ПОЇЗДКИ ЗА КОРДОН
# 2  дніпропетровська  ВТОРИННА РЕЄСТРАЦІЯ ТЗ, ПРИДБАНОГО В ТОРГОВЕЛЬ...
# 3     тернопільська                                                NaN
# 4     тернопільська                                                NaN
#
#        brand_new
# 0     SSANG YONG
# 1         TOYOTA
# 2          SKODA
# 3        CITROEN
# 4  MERCEDES-BENZ
#
# [5 rows x 23 columns]

# %% [markdown]
# ### топ __нових__ реєстрацій автомобілів за маркою

# %%
data.reset_index(inplace = True)

# %%
# робимо сабсет даних для візуалізації
barplot_brands = data[["brand_new","oper_code","person", "kind", "make_year"]]
barplot_brands = barplot_brands.loc[
    barplot_brands["oper_code"].isin(["30", "100", "11", "20", "10", "120", "99", "172", "105", "17"])] # фільтруємо ті реєстраційні операції, які нам потрібні

barplot_brands = barplot_brands.loc[
    barplot_brands["person"] == "P"] # вибираємо тип покупця, в даному випадку фізичні особи

barplot_brands = barplot_brands.loc[
    barplot_brands["kind"] == "ЛЕГКОВИЙ"] # вибираємо тип автомобіля

barplot_brands = barplot_brands.loc[
    barplot_brands["make_year"] >= 2000] # обираємо рік випуску автомобіля

# робимо зведену таблицю для простоти візуалізації
barplot_brands = pd.pivot_table(barplot_brands, index = "brand_new", aggfunc="count")
barplot_brands = barplot_brands.sort_values("oper_code", ascending = False) #сортуємо дані в порядку спадання

# %% [markdown]
# Посилання на документацію https://seaborn.pydata.org/generated/seaborn.barplot.html

# %%
# треба скину    пкупупу мапукеуцкцкити індекс, який ми отримали через сводну таблицю, для того щоб побудувати графік (при зміні налаштувань графіка застосовується лише раз)
barplot_brands.reset_index(inplace = True)

# %%
barplot = sns.barplot(
    data=barplot_brands.iloc[:19], # Кількість записів у ТОП, можемо редагувати під час оголошення графіку
    x="oper_code",
    y = "brand_new",
    color="#0b7fab",
)

sns.set_theme(
    style = "white",
    rc={'figure.figsize':(15,11)}
)

barplot.set(xlabel ='кількість реєстрацій', ylabel='')
barplot.set(title = "Рейтинг найпопулярніших марок авто в Україні")
# Out:
# [Text(0.5, 1.0, 'Рейтинг найпопулярніших марок авто в Україні')]

# %% [markdown]
# ### топ __нових__ реєстрацій автомобілів за моделлю - фізичні особи

# %% [markdown]
# ### топ __нових__ реєстрацій автомобілв за моделлю бізнесом

# %%
# об'єднуємо стовпчик "марка" та "модель" для отримання унікальних записів
data["brand_model"] = data[["brand_new", "model"]].apply(tuple, axis=1)
data.head()
# Out:
#              index  Unnamed: 0 person  reg_addr_koatuu oper_code  \
# 0                0           0      P     5.101370e+08        40
# 1                1           1      P     5.110137e+09       230
# 2                2           2      P     2.310137e+09        40
# 3                3           3      P     6.110100e+09       400
# 4                4           4      P     6.110100e+09       400
# ...            ...         ...    ...              ...       ...
# 13366354  13366354      443461      P              NaN        71
# 13366355  13366355      443462      P     5.104000e+08       308
# 13366356  13366356      443463      P     5.101000e+08        71
# 13366357  13366357      443464      P              NaN       308
# 13366358  13366358      443465      P     7.410137e+09       308
#
#                                                   oper_name       d_reg  \
# 0         40 - ВТОРИННА РЕЄСТРАЦІЯ ТЗ, ПРИДБАНОГО В ТОРГ...  2013-01-16
# 1         230 -  ВИДАЧА СВ. ПРО РЕЄСТР ДЛЯ ПОЇЗДКИ ЗА КО...  2013-08-29
# 2         40 - ВТОРИННА РЕЄСТРАЦІЯ ТЗ, ПРИДБАНОГО В ТОРГ...  2013-02-02
# 3         400 - ПЕРЕРЕЄСТРАЦIЯ ПРИ ПЕРЕОБЛАДНАННI БЕЗ ЗА...  2013-01-26
# 4         400 - ПЕРЕРЕЄСТРАЦIЯ ПРИ ПЕРЕОБЛАДНАННI БЕЗ ЗА...  2013-01-05
# ...                                                     ...         ...
# 13366354  РЕЄСТРАЦІЯ ТЗ ПРИВЕЗЕНОГО З-ЗА КОРДОНУ ПО ПОСВ...  05.03.2021
# 13366355  ПЕРЕРЕЄСТРАЦІЯ НА НОВОГО ВЛАСНИКА ЗА ДОГ. КУПI...  16.03.2021
# 13366356  РЕЄСТРАЦІЯ ТЗ ПРИВЕЗЕНОГО З-ЗА КОРДОНУ ПО ПОСВ...  05.03.2021
# 13366357  ПЕРЕРЕЄСТРАЦІЯ НА НОВОГО ВЛАСНИКА ЗА ДОГ. КУПI...  30.03.2021
# 13366358  ПЕРЕРЕЄСТРАЦІЯ НА НОВОГО ВЛАСНИКА ЗА ДОГ. КУПI...  25.03.2021
#
#           dep_code                                                dep  \
# 0          1305301  ВІННИЦЬКИЙ  ВРЕР УДАІ УМВС УКРАЇНИ У ВІННИЦЬКІ...
# 1             5146                                         Центр 5146
# 2             1242                                         Центр 1242
# 3             6141                                         Центр 6141
# 4             6141                                         Центр 6141
# ...            ...                                                ...
# 13366354     12373                                           ТСЦ 6843
# 13366355     12231                                           ТСЦ 0543
# 13366356     12229                                           ТСЦ 0541
# 13366357     12250                                           ТСЦ 1443
# 13366358     13960                                           ТСЦ 8048
#
#                                     brand  ...    purpose                fuel  \
# 0                      SSANG YONG  REXTON  ...  ЗАГАЛЬНИЙ     ДИЗЕЛЬНЕ ПАЛИВО
# 1                          TOYOTA  PREVIA  ...  ЗАГАЛЬНИЙ              БЕНЗИН
# 2                          SKODA  OCTAVIA  ...  ЗАГАЛЬНИЙ              БЕНЗИН
# 3                          CITROEN  JUMPY  ...  ЗАГАЛЬНИЙ     ДИЗЕЛЬНЕ ПАЛИВО
# 4         MERCEDES-BENZ  SPRINTER 313 CDI  ...  ЗАГАЛЬНИЙ     ДИЗЕЛЬНЕ ПАЛИВО
# ...                                   ...  ...        ...                 ...
# 13366354                            SKODA  ...  ЗАГАЛЬНИЙ              БЕНЗИН
# 13366355                          HYUNDAI  ...  ЗАГАЛЬНИЙ     ДИЗЕЛЬНЕ ПАЛИВО
# 13366356                          HYUNDAI  ...  ЗАГАЛЬНИЙ     ДИЗЕЛЬНЕ ПАЛИВО
# 13366357                             FORD  ...  ЗАГАЛЬНИЙ  ЕЛЕКТРО АБО БЕНЗИН
# 13366358                       VOLKSWAGEN  ...  ЗАГАЛЬНИЙ              БЕНЗИН
#
#          capacity own_weight total_weight n_reg_new            region  \
# 0          2696.0     2069.0       2550.0  АВ1923ВТ         вінницька
# 1          2362.0     1720.0       2450.0  ВН8542СО           одеська
# 2          1595.0     1245.0       1720.0  АР6199СІ  дніпропетровська
# 3          1560.0     1736.0       2661.0  ВО5930ВА     тернопільська
# 4          2148.0     1995.0       3500.0  ВО5562ВА     тернопільська
# ...           ...        ...          ...       ...               ...
# 13366354   1595.0       1295         1805  ВХ8612ЕО       хмельницька
# 13366355   2188.0       2030         2570  АВ5529НО         вінницька
# 13366356   2188.0       2030         2570  АВ0875НТ         вінницька
# 13366357   2000.0       1674         2250  АН4178ОН          донецька
# 13366358   1595.0       1502         2090  СВ0975СХ              київ
#
#                                               oper_name_new      brand_new  \
# 0         ВТОРИННА РЕЄСТРАЦІЯ ТЗ, ПРИДБАНОГО В ТОРГОВЕЛЬ...     SSANG YONG
# 1               ВИДАЧА СВ. ПРО РЕЄСТР ДЛЯ ПОЇЗДКИ ЗА КОРДОН         TOYOTA
# 2         ВТОРИННА РЕЄСТРАЦІЯ ТЗ, ПРИДБАНОГО В ТОРГОВЕЛЬ...          SKODA
# 3                                                       NaN        CITROEN
# 4                                                       NaN  MERCEDES-BENZ
# ...                                                     ...            ...
# 13366354                        РЕЄСТРАЦІЯ ТЗ ПРИВЕЗЕНОГО З          SKODA
# 13366355  ПЕРЕРЕЄСТРАЦІЯ НА НОВОГО ВЛАСНИКА ЗА ДОГ. КУПIВЛI        HYUNDAI
# 13366356                        РЕЄСТРАЦІЯ ТЗ ПРИВЕЗЕНОГО З        HYUNDAI
# 13366357  ПЕРЕРЕЄСТРАЦІЯ НА НОВОГО ВЛАСНИКА ЗА ДОГ. КУПIВЛI           FORD
# 13366358  ПЕРЕРЕЄСТРАЦІЯ НА НОВОГО ВЛАСНИКА ЗА ДОГ. КУПIВЛI     VOLKSWAGEN
#
#                                 brand_model
# 0                      (SSANG YONG, REXTON)
# 1                          (TOYOTA, PREVIA)
# 2                          (SKODA, OCTAVIA)
# 3                          (CITROEN, JUMPY)
# 4         (MERCEDES-BENZ, SPRINTER 313 CDI)
# ...                                     ...
# 13366354             (SKODA, OCTAVIA COMBI)
# 13366355                (HYUNDAI, SANTA FE)
# 13366356                (HYUNDAI, SANTA FE)
# 13366357                      (FORD, C-MAX)
# 13366358               (VOLKSWAGEN, TOURAN)
#
# [13366359 rows x 25 columns]

# %%
model_j = pd.pivot_table(data, index = "brand_model", aggfunc="count")
model_j = model_j.sort_values("body", ascending = False)
model_j.head()
# Out:
#                                 Unnamed: 0    body   brand  brand_new  \
# brand_model
# (DAEWOO, LANOS)                     240167  240167  240167     240167
# (VOLKSWAGEN, PASSAT)                219817  219817  219817     219817
# (VOLKSWAGEN, TRANSPORTER)           186803  186803  186803     186803
# (RENAULT, KANGOO)                   168295  168295  168295     168295
# (CHEVROLET, AVEO)                   165171  165171  165171     165171
# ...                                    ...     ...     ...        ...
# (ЕТАЛОН, T-713.35)                       1       1       1          1
# (MERCEDES-BENZ, ACTROS 2644LS)           1       1       1          1
# (MERCEDES-BENZ, ACTROS 2663LS)           1       1       1          1
# (ЕРАЗ, 762Е)                             1       1       1          1
# (NFP-EUROTRAILER, SKS 18-7.5)            1       1       1          1
#
#                                 capacity   color   d_reg     dep  dep_code  \
# brand_model
# (DAEWOO, LANOS)                   240081  240167  240167  240167    240167
# (VOLKSWAGEN, PASSAT)              219779  219817  219817  219817    219817
# (VOLKSWAGEN, TRANSPORTER)         186777  186803  186803  186803    186803
# (RENAULT, KANGOO)                 166343  168295  168295  168295    168295
# (CHEVROLET, AVEO)                 165156  165171  165171  165171    165171
# ...                                  ...     ...     ...     ...       ...
# (ЕТАЛОН, T-713.35)                     1       1       1       1         1
# (MERCEDES-BENZ, ACTROS 2644LS)         1       1       1       1         1
# (MERCEDES-BENZ, ACTROS 2663LS)         1       1       1       1         1
# (ЕРАЗ, 762Е)                           1       1       1       1         1
# (NFP-EUROTRAILER, SKS 18-7.5)          0       1       1       1         1
#
#                                   fuel  ...  n_reg_new  oper_code  oper_name  \
# brand_model                             ...
# (DAEWOO, LANOS)                 239915  ...     239914     240167     240167
# (VOLKSWAGEN, PASSAT)            219667  ...     219540     219817     219817
# (VOLKSWAGEN, TRANSPORTER)       186803  ...     186688     186803     186803
# (RENAULT, KANGOO)               168275  ...     168223     168295     168295
# (CHEVROLET, AVEO)               165170  ...     165064     165171     165171
# ...                                ...  ...        ...        ...        ...
# (ЕТАЛОН, T-713.35)                   1  ...          1          1          1
# (MERCEDES-BENZ, ACTROS 2644LS)       1  ...          1          1          1
# (MERCEDES-BENZ, ACTROS 2663LS)       1  ...          1          1          1
# (ЕРАЗ, 762Е)                         1  ...          0          1          1
# (NFP-EUROTRAILER, SKS 18-7.5)        0  ...          1          1          1
#
#                                 oper_name_new  own_weight  person  purpose  \
# brand_model
# (DAEWOO, LANOS)                        207518      239490  240167   240167
# (VOLKSWAGEN, PASSAT)                   210586      218979  219817   219817
# (VOLKSWAGEN, TRANSPORTER)              163584      184776  186803   186803
# (RENAULT, KANGOO)                      145501      167281  168295   168295
# (CHEVROLET, AVEO)                      144536      164724  165171   165171
# ...                                       ...         ...     ...      ...
# (ЕТАЛОН, T-713.35)                          1           1       1        1
# (MERCEDES-BENZ, ACTROS 2644LS)              1           1       1        1
# (MERCEDES-BENZ, ACTROS 2663LS)              1           1       1        1
# (ЕРАЗ, 762Е)                                1           1       1        1
# (NFP-EUROTRAILER, SKS 18-7.5)               1           1       1        1
#
#                                 reg_addr_koatuu  region  total_weight
# brand_model
# (DAEWOO, LANOS)                          230998  240167        240065
# (VOLKSWAGEN, PASSAT)                     205085  219817        219514
# (VOLKSWAGEN, TRANSPORTER)                182802  186803        186681
# (RENAULT, KANGOO)                        163264  168295        168228
# (CHEVROLET, AVEO)                        158883  165171        165118
# ...                                         ...     ...           ...
# (ЕТАЛОН, T-713.35)                            1       1             1
# (MERCEDES-BENZ, ACTROS 2644LS)                1       1             1
# (MERCEDES-BENZ, ACTROS 2663LS)                1       1             1
# (ЕРАЗ, 762Е)                                  1       1             1
# (NFP-EUROTRAILER, SKS 18-7.5)                 1       1             1
#
# [38702 rows x 24 columns]

# %%
# треба скинути індекс, який ми отримали через сводну таблицю, для того щоб побудувати графік (при зміні налаштувань графіка застосовується лише раз)
model_j.reset_index(inplace = True)

# %%
barplot = sns.barplot(
    data=model_j.iloc[:19], # Кількість записів у ТОП, можемо редагувати під час оголошення графіку
    x="body",
    y = "brand_model",
    color="#0b7fab",
)

sns.set_theme(
    style = "white",
    rc={'figure.figsize':(15,11)}
)

barplot.set(title = "Рейтинг найпопулярніших моделей авто в Україні")
barplot.set(xlabel ='Кількість реєстрацій', ylabel='')
# Out:
# [Text(0.5, 0, 'Кількість реєстрацій'), Text(0, 0.5, '')]

# %% [markdown]
# ### топ реєстраційних дій за моделлю авто (підрахунок кількості значень у наборі)

# %% [markdown]
# ### Порівняння на барчарті кількості __нових__ реєстрацій АВТО за весь час з 2013 року (data["oper_code"] :

# %% [markdown]
# ### Сітка лайн чартів із порівнянням кількості __нових__ реєстрацій по областях

# %%
# Create a dataset with many short random walks
linechart_registrations = data[["brand_new","oper_code","person", "kind", "d_reg", "region"]]
linechart_registrations["oper_code"] = linechart_registrations["oper_code"].astype(str)

linechart_registrations = linechart_registrations.loc[
    linechart_registrations["oper_code"].isin(["30", "100", "11", "20", "10", "120", "99"])] # фільтруємо ті реєстраційні операції, які нам потрібні

linechart_registrations = linechart_registrations.loc[
    linechart_registrations["person"] == "P"] # вибираємо тип покупця, в даному випадку фізичні особи

linechart_registrations = linechart_registrations.loc[
    linechart_registrations["kind"] == "ЛЕГКОВИЙ"] # вибираємо тип автомобіля

linechart_registrations = pd.pivot_table(linechart_registrations, index = "region", values = "d_reg",aggfunc="count" )
# Out:
# <ipython-input-58-75be64f2c4fe>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   linechart_registrations["oper_code"] = linechart_registrations["oper_code"].astype(str)
#            brand_new oper_code person      kind       d_reg            region
# 9383981   VOLKSWAGEN       100      P  ЛЕГКОВИЙ  01.02.2019        рівненська
# 9799390       NISSAN       100      P  ЛЕГКОВИЙ  01.02.2019         волинська
# 10257726       SKODA        99      P  ЛЕГКОВИЙ  01.02.2019           одеська
# 10709988       SKODA        99      P  ЛЕГКОВИЙ  01.02.2019  дніпропетровська
# 10905192       SKODA        99      P  ЛЕГКОВИЙ  01.02.2019      миколаївська
# ...              ...       ...    ...       ...         ...               ...
# 11426071        FORD       100      P  ЛЕГКОВИЙ  31.12.2020         львівська
# 11426077     PEUGEOT       100      P  ЛЕГКОВИЙ  31.12.2020       хмельницька
# 11426191       HONDA       100      P  ЛЕГКОВИЙ  31.12.2020  дніпропетровська
# 11426195        OPEL       100      P  ЛЕГКОВИЙ  31.12.2020       житомирська
# 12145807       SKODA       100      P  ЛЕГКОВИЙ  31.12.2020        полтавська
#
# [484063 rows x 6 columns]

# %%
sns.set_theme(style="ticks")
# ініціюємо сітку графіків для кожного регіону
grid = sns.FacetGrid(linechart_registrations, col="region", col_wrap=5, height=3)

# Draw a horizontal line to show the starting point
#grid.map(plt.axhline, y=0, ls=":", c=".5")

# Draw a line plot to show the trajectory of each random walk
grid.map(plt.plot, "d_reg", marker="o")

# Adjust the tick positions and labels
grid.set(xticks=np.arange(5), yticks=[-3, 3],
         xlim=(-.5, 4.5), ylim=(-3.5, 3.5))

# Adjust the arrangement of the plots
grid.fig.tight_layout(w_pad=1)
# Out:
# <ipython-input-45-8d0f9e8ada13>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   linechart_registrations["oper_code"] = linechart_registrations["oper_code"].astype(str)

# %% [markdown]
# ### Хронологія __нових__ та __повторних__ реєстрації електрокарів
